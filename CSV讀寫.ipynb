# %%
#擷取相同的名字
import csv
import os
import sys

pathProg = 'C:\\Users\\tonywang\\Desktop'
os.chdir(pathProg)

if os.getcwd() != pathProg:
    print("EEROR: the file path incorrect.")
    sys.exit()

file = open(pathProg + '\calc_case_path_train_density.csv', 'r')
csvCursor = csv.reader(file)

for row in csvCursor:
    #print(row[0])
    #print(row[3] )
    string = str(row[3])
    print(string[42:49])
file.close()
# Out:
# P_00010
# P_00011
# P_00011
# P_00012
# P_00012
# P_00013
# P_00014
# P_00014
# P_00016
# P_00016
# P_00019
# P_00019
# P_00020
# P_00020
# P_00022
# P_00022
# P_00024
# P_00024
# P_00028
# P_00029
# P_00029
# P_00030
# P_00030
# P_00030
# P_00030
# P_00031
# P_00034
# P_00034
# P_00043
# P_00047
# P_00047
# P_00048
# P_00048
# P_00049
# P_00049
# P_00060
# P_00060
# P_00062
# P_00062
# P_00063
# P_00063
# P_00071
# P_00071
# P_00078
# P_00078
# P_00083
# P_00084
# P_00084
# P_00085
# P_00085
# P_00088
# P_00088
# P_00091
# P_00091
# P_00098
# P_00098
# P_00098
# P_00098
# P_00101
# P_00101
# P_00105
# P_00105
# P_00106
# P_00106
# P_00112
# P_00112
# P_00112
# P_00112
# P_00121
# P_00121
# P_00123
# P_00123
# P_00129
# P_00129
# P_00136
# P_00136
# P_00151
# P_00157
# P_00157
# P_00159
# P_00159
# P_00161
# P_00162
# P_00162
# P_00179
# P_00179
# P_00181
# P_00181
# P_00182
# P_00182
# P_00183
# P_00185
# P_00185
# P_00188
# P_00189
# P_00189
# P_00196
# P_00196
# P_00197
# P_00197
# ...

# %%
#把CSV對照相同的檔案印出br
import csv
import os
import sys

pathProg = 'C:\\Users\\tonywang\\Desktop'
os.chdir(pathProg)

if os.getcwd() != pathProg:
    print("EEROR: the file path incorrect.")
    sys.exit()

file = open(pathProg + '\calc_case_description_train_set.csv', 'r')
csvCursor = csv.reader(file)
a1=[]
a2=[]
for row in csvCursor:  
    #print(row[0],row[4])
    a1.append(row[4])
    a2.append(row[0:2])
#print(a1)

for x in a1:
    #print(x)
    #print(x[0])
    for y in a2:
        if x in y:
            print(y[1])
            break;

file.close()
# Out:
# 3
# 3
# 3
# 2
# 2
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 2
# 2
# 3
# 3
# 4
# 4
# 4
# 3
# 3
# 2
# 2
# 2
# 2
# 4
# 3
# 3
# 3
# 2
# 2
# 1
# 1
# 4
# 4
# 3
# 3
# 3
# 3
# 2
# 2
# 2
# 2
# 2
# 2
# 4
# 3
# 3
# 2
# 2
# 4
# 4
# 3
# 3
# 4
# 4
# 4
# 4
# 3
# 3
# 3
# 3
# 1
# 1
# 3
# 3
# 3
# 3
# 2
# 2
# 3
# 3
# 2
# 2
# 3
# 3
# 4
# 3
# 3
# 2
# 2
# 4
# 2
# 2
# 3
# 3
# 4
# 4
# 2
# 2
# 3
# 2
# 2
# 3
# 4
# 4
# 4
# 4
# 1
# 1
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 4
# 4
# 4
# 4
# 3
# 4
# 3
# 3
# 4
# 4
# 3
# 3
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 3
# 3
# 4
# 4
# 1
# 1
# 2
# 3
# 3
# 3
# 3
# 2
# 2
# 3
# 3
# 2
# 2
# 1
# 1
# 3
# 3
# 3
# 3
# 4
# 4
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 3
# 3
# 4
# 4
# 4
# 4
# 4
# 1
# 1
# 2
# 2
# 4
# 4
# 4
# 4
# 4
# 2
# 2
# 3
# 3
# 2
# 2
# 1
# 1
# 3
# 4
# 4
# 1
# 1
# 4
# 4
# 4
# 4
# 4
# 4
# 2
# 2
# 2
# 2
# 2
# 2
# 3
# 3
# 2
# 2
# 1
# 1
# 3
# 3
# 4
# 4
# 2
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 1
# 1
# 1
# 1
# 4
# 4
# 2
# 2
# 3
# 3
# 3
# 3
# 2
# 2
# 2
# 2
# 1
# 1
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# ...
