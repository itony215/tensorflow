# %%
import csv
import os
import sys
from datetime import datetime
import cv2
import numpy as np
import matplotlib.pyplot as plt 
# %matplotlib inline
import SimpleITK as sitk
from time import strftime
mass_training_file = "D:\\DDSM\\total_case_path_train_density.csv"
f = open(mass_training_file, 'r')
def rotate90(src):
        img_copy = src.copy()
        img_copy = cv2.transpose(img_copy)
        img_copy = cv2.flip(img_copy, 1)
        return img_copy
def flip(src):
        img_copy = src.copy()
        img_copy = cv2.flip(img_copy, 1)
        return img_copy    
def read_dcm_image(path):
        ds = sitk.ReadImage(path)
        img_array = sitk.GetArrayFromImage(ds)
        return img_array[0]
a=1
b=1
c=1
d=1    
num_line=0
for line in f:
    if num_line >=10:
        break
    num_line += 1
    line = line.rstrip()
    l = line.split(",")
    if len(l) <= 2:
        continue
    print("Loading training data:" + l[0])
    image_path = l[2] + l[3]
    img = (read_dcm_image(image_path))
    print(img.shape)
    splity=[]
    splitx=[]
    for i in range(img.shape[1]):
        if( sum( img[:,i] )/img.shape[0] > 2000 ):
            splity.append(i)
    #print(splity)
    for i in range(img.shape[0]):
        if( sum( img[i,:] )/img.shape[1] > 2000 ):
            splitx.append(i)
    #print(splitx)
    count=0
    start=[]
    find=[]
    for i in range(len(splitx)-1):
        if splitx[i+1]-splitx[i]==1:
            if count==0:
                start.append(i)
            count=count+1
        else:
            if count != 0:
                find.append(count)
            count=0
    if find ==[]:
        find.append(len(splitx)-1)

    p=find.index(max(find)) 
    
    county=0
    starty=[]
    findy=[]
    for i in range(len(splity)-1):
        if splity[i+1]-splity[i]==1:
            if county==0:
                starty.append(i)
            county=county+1
        else:
            if county != 0:
                findy.append(county)
            county=0
    if findy ==[]:
        findy.append(len(splity)-1)

    py=findy.index(max(findy)) 
    print('x_start',start[p])
    print('x_length',find[p])
    print('y_start',starty[py])
    print('y_length',findy[py])
    cutimg=img[start[p]:start[p]+find[p],starty[py]:starty[py]+findy[py]]
    
    plt.imshow(cutimg ,cmap='gray')
    plt.title('cut background image')
    plt.axis('off')
    plt.show()
    
    '''
    smallimage=cv2.resize(cutimg,(224,224), interpolation=cv2.INTER_CUBIC)
    d1=rotate90(smallimage)
    d2=rotate90(d1)
    d3=rotate90(d2)
    f1=flip(smallimage)
    f2=flip(d1)
    f3=flip(d2)
    f4=flip(d3)
    print(l[1])
    if l[1]==str(1):
        cv2.imwrite('C'+l[1]+'_'+str(a)+'.png', smallimage)
        a=a+1
        cv2.imwrite('C'+l[1]+'_'+str(a)+'.png', d1)
        a=a+1
        cv2.imwrite('C'+l[1]+'_'+str(a)+'.png', d2)
        a=a+1
        cv2.imwrite('C'+l[1]+'_'+str(a)+'.png', d3)
        a=a+1
        cv2.imwrite('C'+l[1]+'_'+str(a)+'.png', f1)
        a=a+1
        cv2.imwrite('C'+l[1]+'_'+str(a)+'.png', f2)
        a=a+1
        cv2.imwrite('C'+l[1]+'_'+str(a)+'.png', f3)
        a=a+1
        cv2.imwrite('C'+l[1]+'_'+str(a)+'.png', f4)
        a=a+1
        print("save1")
    elif l[1]==str(2):
        cv2.imwrite('C'+l[1]+'_'+str(b)+'.png', smallimage)
        b=b+1
        cv2.imwrite('C'+l[1]+'_'+str(b)+'.png', d1)
        b=b+1
        cv2.imwrite('C'+l[1]+'_'+str(b)+'.png', d2)
        b=b+1
        cv2.imwrite('C'+l[1]+'_'+str(b)+'.png', d3)
        b=b+1
        cv2.imwrite('C'+l[1]+'_'+str(b)+'.png', f1)
        b=b+1
        cv2.imwrite('C'+l[1]+'_'+str(b)+'.png', f2)
        b=b+1
        cv2.imwrite('C'+l[1]+'_'+str(b)+'.png', f3)
        b=b+1
        cv2.imwrite('C'+l[1]+'_'+str(b)+'.png', f4)
        b=b+1
        print("save2")
    elif l[1]==str(3):
        cv2.imwrite('C'+l[1]+'_'+str(c)+'.png', smallimage)
        c=c+1
        cv2.imwrite('C'+l[1]+'_'+str(c)+'.png', d1)
        c=c+1
        cv2.imwrite('C'+l[1]+'_'+str(c)+'.png', d2)
        c=c+1
        cv2.imwrite('C'+l[1]+'_'+str(c)+'.png', d3)
        c=c+1
        cv2.imwrite('C'+l[1]+'_'+str(c)+'.png', f1)
        c=c+1
        cv2.imwrite('C'+l[1]+'_'+str(c)+'.png', f2)
        c=c+1
        cv2.imwrite('C'+l[1]+'_'+str(c)+'.png', f3)
        c=c+1
        cv2.imwrite('C'+l[1]+'_'+str(c)+'.png', f4)
        c=c+1
        print("save3")
    elif l[1]==str(4):
        cv2.imwrite('C'+l[1]+'_'+str(d)+'.png', smallimage)
        d=d+1
        cv2.imwrite('C'+l[1]+'_'+str(d)+'.png', d1)
        d=d+1
        cv2.imwrite('C'+l[1]+'_'+str(d)+'.png', d2)
        d=d+1
        cv2.imwrite('C'+l[1]+'_'+str(d)+'.png', d3)
        d=d+1
        cv2.imwrite('C'+l[1]+'_'+str(d)+'.png', f1)
        d=d+1
        cv2.imwrite('C'+l[1]+'_'+str(d)+'.png', f2)
        d=d+1
        cv2.imwrite('C'+l[1]+'_'+str(d)+'.png', f3)
        d=d+1
        cv2.imwrite('C'+l[1]+'_'+str(d)+'.png', f4)
        d=d+1
        print("save4")
    else:
        print("XXX")
    '''
# Out:
# Loading training data:P_00001
# (4808, 3024)
# x_start 303
# x_length 3536
# y_start 0
# y_length 1777
# Loading training data:P_00001
# (4800, 2656)
# x_start 0
# x_length 4058
# y_start 0
# y_length 2072
# Loading training data:P_00004
# (5491, 2986)
# x_start 208
# x_length 4469
# y_start 137
# y_length 256
# Loading training data:P_00004
# (5491, 3046)
# x_start 0
# x_length 5067
# y_start 123
# y_length 139
# Loading training data:P_00004
# (5491, 2911)
# x_start 0
# x_length 5490
# y_start 0
# y_length 1950
# Loading training data:P_00009
# (4441, 2206)
# x_start 0
# x_length 3276
# y_start 0
# y_length 1486
# Loading training data:P_00009
# (5266, 2596)
# x_start 0
# x_length 4706
# y_start 0
# y_length 1840
# Loading training data:P_00015
# (5552, 4000)
# x_start 0
# x_length 4957
# y_start 0
# y_length 2248
# Loading training data:P_00018
# (4720, 2584)
# x_start 179
# x_length 3287
# y_start 0
# y_length 81
# Loading training data:P_00018
# (4664, 2544)
# x_start 0
# x_length 3964
# y_start 0
# y_length 1665

# %%
import csv
import os
import random
import sys
from datetime import datetime
import cv2
import numpy as np
import matplotlib.pyplot as plt 
# %matplotlib inline
import SimpleITK as sitk
from time import strftime
mass_training_file = "D:\\DDSM\\total_case_path_train_density.csv"
f = open(mass_training_file, 'r')
def rotate90(src):
        img_copy = src.copy()
        img_copy = cv2.transpose(img_copy)
        img_copy = cv2.flip(img_copy, 1)
        return img_copy
def flip(src):
        img_copy = src.copy()
        img_copy = cv2.flip(img_copy, 1)
        return img_copy    
def read_dcm_image(path):
        ds = sitk.ReadImage(path)
        img_array = sitk.GetArrayFromImage(ds)
        return img_array[0]
a=1
b=1
c=1
d=1    
num_line=0
for line in f:
    if num_line >=2461:
        break
    num_line += 1
    line = line.rstrip()
    l = line.split(",")
    if len(l) <= 2:
        continue
    print("Loading training data:" + l[0])
    image_path = l[2] + l[3]
    img = (read_dcm_image(image_path))
    
    print(img.shape)
    splity=[]
    splitx=[]
    howbig= random.randint(100,500)
    print('howbig',howbig)
    for i in range(img.shape[1]):
        if( sum( img[:,i] )/img.shape[0] > howbig ):
            splity.append(i)
    #print(splity)
    for i in range(img.shape[0]):
        if( sum( img[i,:] )/img.shape[1] > howbig ):
            splitx.append(i)
    #print(splitx)
    count=0
    start=[]
    find=[]
    splitx.append(0)
    for i in range(len(splitx)-1):
        if splitx[i+1]-splitx[i]==1:
            if count==0:
                start.append(i)
            count=count+1
        else:
            if count != 0:
                find.append(count)
                #print('x_len',count)
            count=0
    p=find.index(max(find)) 
    
    county=0
    starty=[]
    findy=[]
    splity.append(0)
    for i in range(len(splity)-1):
        if splity[i+1]-splity[i]==1:
            if county==0:
                starty.append(i)
            county=county+1
        else:
            if county != 0:
                findy.append(county)
                #print('y_len',county)
            county=0
    py=findy.index(max(findy)) 
    print('x_start',start)
    print('x_length',find)
    print('y_start',starty)
    print('y_length',findy)
    print('start[p]',start[p])
    print('start[p]+find[p]',start[p]+find[p])
    print('starty[py]',starty[py])
    print('starty[py]+findy[py]',starty[py]+findy[py])
    cutimg=img[start[p]:start[p]+find[p],starty[py]:starty[py]+findy[py]]
    '''
    plt.imshow(cutimg ,cmap='gray')
    plt.title('cut background image')
    plt.axis('off')
    plt.show()
    '''
    smallimage=cv2.resize(cutimg,(224,224), interpolation=cv2.INTER_CUBIC)
    d1=rotate90(smallimage)
    d2=rotate90(d1)
    d3=rotate90(d2)
    f1=flip(smallimage)
    f2=flip(d1)
    f3=flip(d2)
    f4=flip(d3)
    print(l[1])
    if l[1]==str(1):
        cv2.imwrite('C'+l[1]+'_'+str(a)+'.png', smallimage)
        a=a+1
        cv2.imwrite('C'+l[1]+'_'+str(a)+'.png', d1)
        a=a+1
        cv2.imwrite('C'+l[1]+'_'+str(a)+'.png', d2)
        a=a+1
        cv2.imwrite('C'+l[1]+'_'+str(a)+'.png', d3)
        a=a+1
        cv2.imwrite('C'+l[1]+'_'+str(a)+'.png', f1)
        a=a+1
        cv2.imwrite('C'+l[1]+'_'+str(a)+'.png', f2)
        a=a+1
        cv2.imwrite('C'+l[1]+'_'+str(a)+'.png', f3)
        a=a+1
        cv2.imwrite('C'+l[1]+'_'+str(a)+'.png', f4)
        a=a+1
        print("save1")
    elif l[1]==str(2):
        cv2.imwrite('C'+l[1]+'_'+str(b)+'.png', smallimage)
        b=b+1
        cv2.imwrite('C'+l[1]+'_'+str(b)+'.png', d1)
        b=b+1
        cv2.imwrite('C'+l[1]+'_'+str(b)+'.png', d2)
        b=b+1
        cv2.imwrite('C'+l[1]+'_'+str(b)+'.png', d3)
        b=b+1
        cv2.imwrite('C'+l[1]+'_'+str(b)+'.png', f1)
        b=b+1
        cv2.imwrite('C'+l[1]+'_'+str(b)+'.png', f2)
        b=b+1
        cv2.imwrite('C'+l[1]+'_'+str(b)+'.png', f3)
        b=b+1
        cv2.imwrite('C'+l[1]+'_'+str(b)+'.png', f4)
        b=b+1
        print("save2")
    elif l[1]==str(3):
        cv2.imwrite('C'+l[1]+'_'+str(c)+'.png', smallimage)
        c=c+1
        cv2.imwrite('C'+l[1]+'_'+str(c)+'.png', d1)
        c=c+1
        cv2.imwrite('C'+l[1]+'_'+str(c)+'.png', d2)
        c=c+1
        cv2.imwrite('C'+l[1]+'_'+str(c)+'.png', d3)
        c=c+1
        cv2.imwrite('C'+l[1]+'_'+str(c)+'.png', f1)
        c=c+1
        cv2.imwrite('C'+l[1]+'_'+str(c)+'.png', f2)
        c=c+1
        cv2.imwrite('C'+l[1]+'_'+str(c)+'.png', f3)
        c=c+1
        cv2.imwrite('C'+l[1]+'_'+str(c)+'.png', f4)
        c=c+1
        print("save3")
    elif l[1]==str(4):
        cv2.imwrite('C'+l[1]+'_'+str(d)+'.png', smallimage)
        d=d+1
        cv2.imwrite('C'+l[1]+'_'+str(d)+'.png', d1)
        d=d+1
        cv2.imwrite('C'+l[1]+'_'+str(d)+'.png', d2)
        d=d+1
        cv2.imwrite('C'+l[1]+'_'+str(d)+'.png', d3)
        d=d+1
        cv2.imwrite('C'+l[1]+'_'+str(d)+'.png', f1)
        d=d+1
        cv2.imwrite('C'+l[1]+'_'+str(d)+'.png', f2)
        d=d+1
        cv2.imwrite('C'+l[1]+'_'+str(d)+'.png', f3)
        d=d+1
        cv2.imwrite('C'+l[1]+'_'+str(d)+'.png', f4)
        d=d+1
        print("save4")
    else:
        print("XXX")
# Out:
# Loading training data:P_00001
# (4808, 3024)
# howbig 425
# x_start [0]
# x_length [4807]
# y_start [0, 1850, 2527]
# y_length [1849, 676, 211]
# start[p] 0
# start[p]+find[p] 4807
# starty[py] 0
# starty[py]+findy[py] 1849
# 3
# save3
# Loading training data:P_00001
# (4800, 2656)
# howbig 197
# x_start [0, 4264]
# x_length [4263, 153]
# y_start [0]
# y_length [2655]
# start[p] 0
# start[p]+find[p] 4263
# starty[py] 0
# starty[py]+findy[py] 2655
# 3
# save3
# Loading training data:P_00004
# (5491, 2986)
# howbig 470
# x_start [0, 237, 239, 244, 246]
# x_length [230, 1, 3, 1, 5211]
# y_start [0]
# y_length [2985]
# start[p] 246
# start[p]+find[p] 5457
# starty[py] 0
# starty[py]+findy[py] 2985
# 3
# save3
# Loading training data:P_00004
# (5491, 3046)
# howbig 268
# x_start [0]
# x_length [5490]
# y_start [0]
# y_length [3045]
# start[p] 0
# start[p]+find[p] 5490
# starty[py] 0
# starty[py]+findy[py] 3045
# 3
# save3
# Loading training data:P_00004
# (5491, 2911)
# howbig 371
# x_start [0]
# x_length [5490]
# y_start [0]
# y_length [2910]
# start[p] 0
# start[p]+find[p] 5490
# starty[py] 0
# starty[py]+findy[py] 2910
# 3
# save3
# Loading training data:P_00009
# (4441, 2206)
# howbig 444
# x_start [0]
# x_length [4004]
# y_start [0, 1567]
# y_length [1566, 1]
# start[p] 0
# start[p]+find[p] 4004
# starty[py] 0
# starty[py]+findy[py] 1566
# 3
# save3
# Loading training data:P_00009
# (5266, 2596)
# howbig 162
# x_start [0]
# x_length [5241]
# y_start [0, 1942, 1946, 1951]
# y_length [1941, 2, 4, 533]
# start[p] 0
# start[p]+find[p] 5241
# starty[py] 0
# starty[py]+findy[py] 1941
# 3
# save3
# Loading training data:P_00015
# (5552, 4000)
# howbig 392
# x_start [0]
# x_length [5551]
# y_start [0]
# y_length [2318]
# start[p] 0
# start[p]+find[p] 5551
# starty[py] 0
# starty[py]+findy[py] 2318
# 3
# save3
# Loading training data:P_00018
# (4720, 2584)
# howbig 151
# x_start [0]
# x_length [4719]
# y_start [0]
# y_length [2583]
# start[p] 0
# start[p]+find[p] 4719
# starty[py] 0
# starty[py]+findy[py] 2583
# 2
# save2
# Loading training data:P_00018
# (4664, 2544)
# howbig 171
# x_start [0]
# x_length [4663]
# y_start [0]
# y_length [2543]
# start[p] 0
# start[p]+find[p] 4663
# starty[py] 0
# starty[py]+findy[py] 2543
# 2
# save2
# Loading training data:P_00021
# (4424, 2928)
# howbig 215
# x_start [0]
# x_length [4423]
# y_start [0, 1958]
# y_length [1956, 736]
# start[p] 0
# start[p]+find[p] 4423
# starty[py] 0
# starty[py]+findy[py] 1956
# 1
# save1
# Loading training data:P_00021
# (4480, 2904)
# howbig 231
# x_start [0]
# x_length [4479]
# y_start [0, 1891, 2002, 2286, 2451, 2475, 2477]
# y_length [1890, 110, 283, 164, 23, 1, 17]
# start[p] 0
# start[p]+find[p] 4479
# starty[py] 0
# starty[py]+findy[py] 1890
# 1
# save1
# Loading training data:P_00021
# (4568, 2872)
# howbig 167
# x_start [0]
# x_length [4567]
# y_start [0, 560]
# y_length [559, 1842]
# start[p] 0
# start[p]+find[p] 4567
# starty[py] 560
# starty[py]+findy[py] 2402
# 1
# save1
# Loading training data:P_00021
# (4576, 2784)
# howbig 361
# x_start [0, 4384, 4391]
# x_length [4383, 5, 47]
# y_start [0, 670]
# y_length [669, 1746]
# start[p] 0
# start[p]+find[p] 4383
# starty[py] 670
# starty[py]+findy[py] 2416
# 1
# save1
# Loading training data:P_00023
# (5491, 3301)
# howbig 152
# x_start [0]
# x_length [5350]
# y_start [0, 2847, 2850]
# y_length [2845, 1, 201]
# start[p] 0
# start[p]+find[p] 5350
# starty[py] 0
# starty[py]+findy[py] 2845
# 1
# save1
# Loading training data:P_00023
# (6001, 3286)
# howbig 257
# x_start [0]
# x_length [6000]
# y_start [0]
# y_length [3285]
# start[p] 0
# start[p]+find[p] 6000
# starty[py] 0
# starty[py]+findy[py] 3285
# 1
# save1
# Loading training data:P_00026
# (6706, 3421)
# howbig 155
# x_start [0]
# x_length [6705]
# y_start [0]
# y_length [3420]
# start[p] 0
# start[p]+find[p] 6705
# starty[py] 0
# starty[py]+findy[py] 3420
# 2
# save2
# Loading training data:P_00026
# (6796, 3361)
# howbig 459
# x_start [0]
# x_length [6795]
# y_start [0]
# y_length [3360]
# start[p] 0
# start[p]+find[p] 6795
# starty[py] 0
# starty[py]+findy[py] 3360
# 2
# save2
# Loading training data:P_00027
# (5896, 3800)
# howbig 269
# x_start [0, 136, 580]
# x_length [135, 442, 4941]
# y_start [0]
# y_length [3799]
# start[p] 580
# start[p]+find[p] 5521
# starty[py] 0
# starty[py]+findy[py] 3799
# 2
# save2
# Loading training data:P_00027
# (5904, 3760)
# howbig 209
# x_start [0, 5594, 5602]
# x_length [5588, 7, 143]
# y_start [0]
# y_length [3759]
# start[p] 0
# start[p]+find[p] 5588
# starty[py] 0
# starty[py]+findy[py] 3759
# 2
# save2
# Loading training data:P_00034
# (6451, 3406)
# howbig 292
# x_start [0]
# x_length [6450]
# y_start [0]
# y_length [3405]
# start[p] 0
# start[p]+find[p] 6450
# starty[py] 0
# starty[py]+findy[py] 3405
# 3
# save3
# Loading training data:P_00034
# (6871, 3541)
# howbig 103
# x_start [0]
# x_length [6870]
# y_start [0]
# y_length [3540]
# start[p] 0
# start[p]+find[p] 6870
# starty[py] 0
# starty[py]+findy[py] 3540
# 3
# save3
# Loading training data:P_00039
# (4688, 2704)
# howbig 479
# x_start [0]
# x_length [4687]
# y_start [0]
# y_length [2703]
# start[p] 0
# start[p]+find[p] 4687
# starty[py] 0
# starty[py]+findy[py] 2703
# 2
# save2
# Loading training data:P_00039
# (4720, 2760)
# howbig 205
# x_start [0, 4167]
# x_length [4166, 108]
# y_start [0]
# y_length [2759]
# start[p] 0
# start[p]+find[p] 4166
# starty[py] 0
# starty[py]+findy[py] 2759
# 2
# save2
# Loading training data:P_00041
# (5664, 3984)
# howbig 129
# x_start [0]
# x_length [5663]
# y_start [0, 2922]
# y_length [2921, 695]
# start[p] 0
# start[p]+find[p] 5663
# starty[py] 0
# starty[py]+findy[py] 2921
# 1
# save1
# Loading training data:P_00041
# (5664, 4040)
# howbig 294
# x_start [0]
# x_length [5663]
# y_start [0, 2935, 3181, 3264, 3300]
# y_length [2934, 245, 82, 35, 149]
# start[p] 0
# start[p]+find[p] 5663
# starty[py] 0
# starty[py]+findy[py] 2934
# 1
# save1
# Loading training data:P_00044
# (4504, 2888)
# howbig 171
# x_start [0]
# x_length [4503]
# y_start [0, 97, 102, 546]
# y_length [96, 4, 442, 2058]
# start[p] 0
# start[p]+find[p] 4503
# starty[py] 546
# starty[py]+findy[py] 2604
# 2
# save2
# Loading training data:P_00044
# (4552, 2960)
# howbig 420
# x_start [0]
# x_length [4551]
# y_start [0, 113, 124, 200]
# y_length [112, 10, 75, 2192]
# start[p] 0
# start[p]+find[p] 4551
# starty[py] 200
# starty[py]+findy[py] 2392
# 2
# save2
# Loading training data:P_00045
# (5491, 3166)
# howbig 441
# x_start [0]
# x_length [5490]
# y_start [0]
# y_length [3165]
# start[p] 0
# start[p]+find[p] 5490
# starty[py] 0
# starty[py]+findy[py] 3165
# 4
# save4
# Loading training data:P_00045
# (5491, 3316)
# howbig 229
# x_start [0]
# x_length [5490]
# y_start [0]
# y_length [3315]
# start[p] 0
# start[p]+find[p] 5490
# starty[py] 0
# starty[py]+findy[py] 3315
# 4
# save4
# Loading training data:P_00046
# (4488, 2944)
# howbig 148
# x_start [0]
# x_length [4487]
# y_start [0, 749]
# y_length [748, 1102]
# start[p] 0
# start[p]+find[p] 4487
# starty[py] 749
# starty[py]+findy[py] 1851
# 3
# save3
# Loading training data:P_00051
# (4704, 2472)
# howbig 415
# x_start [0, 104, 4057]
# x_length [103, 3952, 92]
# y_start [0]
# y_length [2471]
# start[p] 104
# start[p]+find[p] 4056
# starty[py] 0
# starty[py]+findy[py] 2471
# 2
# save2
# Loading training data:P_00051
# (4704, 2552)
# howbig 465
# x_start [0]
# x_length [4703]
# y_start [0]
# y_length [2551]
# start[p] 0
# start[p]+find[p] 4703
# starty[py] 0
# starty[py]+findy[py] 2551
# 2
# save2
# Loading training data:P_00054
# (4520, 2920)
# howbig 464
# x_start [0]
# x_length [4519]
# y_start [0, 236, 783]
# y_length [235, 546, 1016]
# start[p] 0
# start[p]+find[p] 4519
# starty[py] 783
# starty[py]+findy[py] 1799
# 4
# save4
# Loading training data:P_00055
# (5386, 3046)
# howbig 242
# x_start [0]
# x_length [5385]
# y_start [0]
# y_length [3045]
# start[p] 0
# start[p]+find[p] 5385
# starty[py] 0
# starty[py]+findy[py] 3045
# 2
# save2
# Loading training data:P_00057
# (4744, 2584)
# howbig 230
# x_start [0, 100, 106, 109, 114]
# x_length [99, 1, 2, 3, 4321]
# y_start [0]
# y_length [2583]
# start[p] 114
# start[p]+find[p] 4435
# starty[py] 0
# starty[py]+findy[py] 2583
# 1
# save1
# Loading training data:P_00057
# (4704, 2680)
# howbig 474
# x_start [0]
# x_length [4703]
# y_start [0]
# y_length [2679]
# start[p] 0
# start[p]+find[p] 4703
# starty[py] 0
# starty[py]+findy[py] 2679
# 1
# save1
# Loading training data:P_00058
# (5311, 4411)
# howbig 421
# x_start [0, 4794]
# x_length [4793, 16]
# y_start [0, 3767]
# y_length [3766, 613]
# start[p] 0
# start[p]+find[p] 4793
# starty[py] 0
# starty[py]+findy[py] 3766
# 2
# save2
# Loading training data:P_00059
# (5386, 3601)
# howbig 172
# x_start [0]
# x_length [5385]
# y_start [0]
# y_length [3600]
# start[p] 0
# start[p]+find[p] 5385
# starty[py] 0
# starty[py]+findy[py] 3600
# 1
# save1
# Loading training data:P_00059
# (5386, 3466)
# howbig 290
# x_start [0]
# x_length [5385]
# y_start [0]
# y_length [3184]
# start[p] 0
# start[p]+find[p] 5385
# starty[py] 0
# starty[py]+findy[py] 3184
# 1
# save1
# Loading training data:P_00061
# (5640, 3800)
# howbig 391
# x_start [0, 117]
# x_length [116, 4460]
# y_start [0, 35, 43, 85]
# y_length [34, 7, 41, 2125]
# start[p] 117
# start[p]+find[p] 4577
# starty[py] 85
# starty[py]+findy[py] 2210
# 2
# save2
# Loading training data:P_00061
# (5448, 4000)
# howbig 149
# x_start [0]
# x_length [5447]
# y_start [0, 49, 73, 100, 142, 190]
# y_length [47, 22, 26, 41, 47, 2322]
# start[p] 0
# start[p]+find[p] 5447
# starty[py] 190
# starty[py]+findy[py] 2512
# 2
# save2
# Loading training data:P_00064
# (4560, 2832)
# howbig 349
# x_start [0]
# x_length [4559]
# y_start [0, 68, 208, 226]
# y_length [67, 139, 17, 1696]
# start[p] 0
# start[p]+find[p] 4559
# starty[py] 226
# starty[py]+findy[py] 1922
# 3
# save3
# Loading training data:P_00065
# (5386, 3331)
# howbig 437
# x_start [0]
# x_length [5385]
# y_start [0, 2842]
# y_length [2841, 251]
# start[p] 0
# start[p]+find[p] 5385
# starty[py] 0
# starty[py]+findy[py] 2841
# 2
# save2
# Loading training data:P_00065
# (5236, 3121)
# howbig 178
# x_start [0]
# x_length [5235]
# y_start [0, 3024]
# y_length [3023, 5]
# start[p] 0
# start[p]+find[p] 5235
# starty[py] 0
# starty[py]+findy[py] 3023
# 2
# save2
# Loading training data:P_00068
# (4784, 3088)
# howbig 213
# x_start [0]
# x_length [4783]
# y_start [0]
# y_length [3087]
# start[p] 0
# start[p]+find[p] 4783
# starty[py] 0
# starty[py]+findy[py] 3087
# 3
# save3
# Loading training data:P_00068
# (4824, 3112)
# howbig 389
# x_start [0, 4222]
# x_length [4221, 156]
# y_start [0]
# y_length [3111]
# start[p] 0
# start[p]+find[p] 4221
# starty[py] 0
# starty[py]+findy[py] 3111
# 3
# save3
# Loading training data:P_00074
# (6301, 3646)
# howbig 493
# x_start [0]
# x_length [6300]
# y_start [0]
# y_length [3645]
# start[p] 0
# start[p]+find[p] 6300
# starty[py] 0
# starty[py]+findy[py] 3645
# 3
# save3
# Loading training data:P_00074
# (6481, 3331)
# howbig 139
# x_start [0]
# x_length [6480]
# y_start [0]
# y_length [3330]
# start[p] 0
# start[p]+find[p] 6480
# starty[py] 0
# starty[py]+findy[py] 3330
# 3
# save3
# Loading training data:P_00074
# (6871, 3451)
# howbig 233
# x_start [0]
# x_length [6870]
# y_start [0]
# y_length [3450]
# start[p] 0
# start[p]+find[p] 6870
# starty[py] 0
# starty[py]+findy[py] 3450
# 3
# save3
# Loading training data:P_00076
# (6526, 3601)
# howbig 129
# x_start [0]
# x_length [6525]
# y_start [0]
# y_length [3600]
# start[p] 0
# start[p]+find[p] 6525
# starty[py] 0
# starty[py]+findy[py] 3600
# 4
# save4
# Loading training data:P_00076
# (6271, 3886)
# howbig 304
# x_start [0]
# x_length [6270]
# y_start [0, 471, 631]
# y_length [470, 159, 3022]
# start[p] 0
# start[p]+find[p] 6270
# starty[py] 631
# starty[py]+findy[py] 3653
# 4
# save4
# Loading training data:P_00079
# (4696, 3226)
# howbig 318
# x_start [0]
# x_length [4695]
# y_start [0, 23]
# y_length [22, 2767]
# start[p] 0
# start[p]+find[p] 4695
# starty[py] 23
# starty[py]+findy[py] 2790
# 2
# save2
# Loading training data:P_00079
# (4951, 3106)
# howbig 341
# x_start [0]
# x_length [4950]
# y_start [0]
# y_length [2620]
# start[p] 0
# start[p]+find[p] 4950
# starty[py] 0
# starty[py]+findy[py] 2620
# 2
# save2
# Loading training data:P_00080
# (4768, 2728)
# howbig 151
# x_start [0]
# x_length [4767]
# y_start [0]
# y_length [2727]
# start[p] 0
# start[p]+find[p] 4767
# starty[py] 0
# starty[py]+findy[py] 2727
# 1
# save1
# Loading training data:P_00080
# (4680, 2840)
# howbig 441
# x_start [0]
# x_length [4679]
# y_start [0]
# y_length [2839]
# start[p] 0
# start[p]+find[p] 4679
# starty[py] 0
# starty[py]+findy[py] 2839
# 1
# save1
# Loading training data:P_00081
# (4704, 2744)
# howbig 398
# x_start [0, 83, 3606]
# x_length [82, 3522, 115]
# y_start [0]
# y_length [2743]
# start[p] 83
# start[p]+find[p] 3605
# starty[py] 0
# starty[py]+findy[py] 2743
# 2
# save2
# Loading training data:P_00081
# (4776, 2704)
# howbig 317
# x_start [0, 4029, 4033]
# x_length [4028, 1, 178]
# y_start [0]
# y_length [2703]
# start[p] 0
# start[p]+find[p] 4028
# starty[py] 0
# starty[py]+findy[py] 2703
# 2
# save2
# Loading training data:P_00086
# (4496, 2960)
# howbig 311
# x_start [0]
# x_length [4495]
# y_start [0, 203, 443]
# y_length [202, 239, 1839]
# start[p] 0
# start[p]+find[p] 4495
# starty[py] 443
# starty[py]+findy[py] 2282
# 2
# save2
# Loading training data:P_00086
# (4504, 2936)
# howbig 270
# x_start [0]
# x_length [4503]
# y_start [0, 157, 380]
# y_length [156, 222, 1985]
# start[p] 0
# start[p]+find[p] 4503
# starty[py] 380
# starty[py]+findy[py] 2365
# 2
# save2
# Loading training data:P_00090
# (4704, 2520)
# howbig 469
# x_start [0, 74, 449, 3707]
# x_length [73, 374, 3257, 103]
# y_start [0]
# y_length [2519]
# start[p] 449
# start[p]+find[p] 3706
# starty[py] 0
# starty[py]+findy[py] 2519
# 2
# save2
# Loading training data:P_00090
# (4696, 2832)
# howbig 449
# x_start [0, 4164]
# x_length [4163, 122]
# y_start [0]
# y_length [2831]
# start[p] 0
# start[p]+find[p] 4163
# starty[py] 0
# starty[py]+findy[py] 2831
# 2
# save2
# Loading training data:P_00092
# (4744, 2392)
# howbig 462
# x_start [0, 118, 542, 3883]
# x_length [117, 423, 3340, 123]
# y_start [0]
# y_length [2391]
# start[p] 542
# start[p]+find[p] 3882
# starty[py] 0
# starty[py]+findy[py] 2391
# 2
# save2
# Loading training data:P_00092
# (4720, 2280)
# howbig 209
# x_start [0]
# x_length [4719]
# y_start [0]
# y_length [2279]
# start[p] 0
# start[p]+find[p] 4719
# starty[py] 0
# starty[py]+findy[py] 2279
# 2
# save2
# Loading training data:P_00092
# (4760, 2552)
# howbig 297
# x_start [0, 107, 3625]
# x_length [106, 3517, 148]
# y_start [0]
# y_length [2551]
# start[p] 107
# start[p]+find[p] 3624
# starty[py] 0
# starty[py]+findy[py] 2551
# 2
# save2
# Loading training data:P_00092
# (4704, 2392)
# howbig 347
# x_start [0, 4408, 4416, 4420, 4427]
# x_length [4407, 7, 2, 6, 127]
# y_start [0]
# y_length [2391]
# start[p] 0
# start[p]+find[p] 4407
# starty[py] 0
# starty[py]+findy[py] 2391
# 2
# save2
# Loading training data:P_00094
# (4560, 2952)
# howbig 465
# x_start [0, 56, 3945]
# x_length [55, 3888, 177]
# y_start [0, 171, 181, 297, 356]
# y_length [170, 9, 115, 58, 1615]
# start[p] 56
# start[p]+find[p] 3944
# starty[py] 356
# starty[py]+findy[py] 1971
# 3
# save3
# Loading training data:P_00094
# (4608, 2888)
# howbig 389
# x_start [0, 4313]
# x_length [4311, 180]
# y_start [0, 72, 358, 461, 494]
# y_length [71, 285, 102, 32, 1906]
# start[p] 0
# start[p]+find[p] 4311
# starty[py] 494
# starty[py]+findy[py] 2400
# 3
# save3
# Loading training data:P_00095
# (5888, 4056)
# howbig 256
# x_start [0, 119, 351, 656, 4341]
# x_length [118, 231, 304, 3684, 475]
# y_start [0]
# y_length [4055]
# start[p] 656
# start[p]+find[p] 4340
# starty[py] 0
# starty[py]+findy[py] 4055
# 2
# save2
# Loading training data:P_00095
# (5848, 4040)
# howbig 196
# x_start [0]
# x_length [5847]
# y_start [0]
# y_length [4039]
# start[p] 0
# start[p]+find[p] 5847
# starty[py] 0
# starty[py]+findy[py] 4039
# 2
# save2
# Loading training data:P_00096
# (5011, 2566)
# howbig 366
# x_start [1, 4203]
# x_length [4201, 2]
# y_start [0]
# y_length [1814]
# start[p] 1
# start[p]+find[p] 4202
# starty[py] 0
# starty[py]+findy[py] 1814
# 1
# save1
# Loading training data:P_00096
# (6661, 2836)
# howbig 272
# x_start [0]
# x_length [6660]
# y_start [0]
# y_length [2835]
# start[p] 0
# start[p]+find[p] 6660
# starty[py] 0
# starty[py]+findy[py] 2835
# 1
# save1
# Loading training data:P_00106
# (5744, 3920)
# howbig 369
# x_start [0]
# x_length [5743]
# y_start [0, 2490]
# y_length [2489, 1018]
# start[p] 0
# start[p]+find[p] 5743
# starty[py] 0
# starty[py]+findy[py] 2489
# 1
# save1
# Loading training data:P_00106
# (5704, 4024)
# howbig 235
# x_start [0]
# x_length [5703]
# y_start [0, 2779, 3079, 3195]
# y_length [2778, 299, 115, 178]
# start[p] 0
# start[p]+find[p] 5703
# starty[py] 0
# starty[py]+findy[py] 2778
# 1
# save1
# Loading training data:P_00106
# (5752, 3928)
# howbig 225
# x_start [0]
# x_length [5751]
# y_start [0, 652, 677, 681]
# y_length [651, 23, 3, 2646]
# start[p] 0
# start[p]+find[p] 5751
# starty[py] 681
# starty[py]+findy[py] 3327
# 1
# save1
# Loading training data:P_00106
# (5768, 3992)
# howbig 475
# x_start [0]
# x_length [5767]
# y_start [0, 582, 594, 611]
# y_length [581, 11, 16, 2698]
# start[p] 0
# start[p]+find[p] 5767
# starty[py] 611
# starty[py]+findy[py] 3309
# 1
# save1
# Loading training data:P_00107
# (4584, 2952)
# howbig 412
# x_start [0]
# x_length [4341]
# y_start [0, 58, 188, 197]
# y_length [57, 129, 8, 1647]
# start[p] 0
# start[p]+find[p] 4341
# starty[py] 197
# starty[py]+findy[py] 1844
# 2
# save2
# Loading training data:P_00108
# (5386, 3391)
# howbig 384
# x_start [0]
# x_length [5385]
# y_start [0, 2589]
# y_length [2588, 102]
# start[p] 0
# start[p]+find[p] 5385
# starty[py] 0
# starty[py]+findy[py] 2588
# 2
# save2
# Loading training data:P_00108
# (5386, 3436)
# howbig 118
# x_start [0]
# x_length [5385]
# y_start [0]
# y_length [3435]
# start[p] 0
# start[p]+find[p] 5385
# starty[py] 0
# starty[py]+findy[py] 3435
# 2
# save2
# Loading training data:P_00109
# (5641, 3796)
# howbig 471
# x_start [0, 192, 214, 245, 275]
# x_length [191, 21, 30, 29, 4725]
# y_start [0, 50, 367, 448, 501]
# y_length [48, 316, 80, 52, 3157]
# start[p] 275
# start[p]+find[p] 5000
# starty[py] 501
# starty[py]+findy[py] 3658
# 3
# save3
# Loading training data:P_00110
# (5611, 2806)
# howbig 110
# x_start [0]
# x_length [5610]
# y_start [0, 3]
# y_length [2, 1935]
# start[p] 0
# start[p]+find[p] 5610
# starty[py] 3
# starty[py]+findy[py] 1938
# 3
# save3
# Loading training data:P_00110
# (6871, 2866)
# howbig 478
# x_start [0]
# x_length [6870]
# y_start [0]
# y_length [2865]
# start[p] 0
# start[p]+find[p] 6870
# starty[py] 0
# starty[py]+findy[py] 2865
# 3
# save3
# Loading training data:P_00110
# (5836, 3286)
# howbig 441
# x_start [0]
# x_length [5307]
# y_start [0]
# y_length [3285]
# start[p] 0
# start[p]+find[p] 5307
# starty[py] 0
# starty[py]+findy[py] 3285
# 3
# save3
# Loading training data:P_00117
# (6871, 4096)
# howbig 293
# x_start [0]
# x_length [6870]
# y_start [0]
# y_length [4095]
# start[p] 0
# start[p]+find[p] 6870
# starty[py] 0
# starty[py]+findy[py] 4095
# 2
# save2
# Loading training data:P_00119
# (6000, 3152)
# howbig 120
# x_start [0]
# x_length [5999]
# y_start [0]
# y_length [3151]
# start[p] 0
# start[p]+find[p] 5999
# starty[py] 0
# starty[py]+findy[py] 3151
# 2
# save2
# Loading training data:P_00119
# (5976, 3272)
# howbig 449
# x_start [0]
# x_length [5975]
# y_start [0]
# y_length [3271]
# start[p] 0
# start[p]+find[p] 5975
# starty[py] 0
# starty[py]+findy[py] 3271
# 2
# save2
# Loading training data:P_00120
# (4528, 2984)
# howbig 390
# x_start [0, 402, 406]
# x_length [400, 1, 3896]
# y_start [0, 1059]
# y_length [1058, 29]
# start[p] 406
# start[p]+find[p] 4302
# starty[py] 0
# starty[py]+findy[py] 1058
# 4
# save4
# Loading training data:P_00120
# (4352, 2824)
# howbig 373
# x_start [0]
# x_length [4351]
# y_start [0, 1230, 1398, 1427]
# y_length [1229, 167, 28, 17]
# start[p] 0
# start[p]+find[p] 4351
# starty[py] 0
# starty[py]+findy[py] 1229
# 4
# save4
# Loading training data:P_00122
# (4592, 2920)
# howbig 176
# x_start [0]
# x_length [4591]
# y_start [0, 85, 87, 557, 717]
# y_length [84, 1, 469, 159, 1660]
# start[p] 0
# start[p]+find[p] 4591
# starty[py] 717
# starty[py]+findy[py] 2377
# 2
# save2
# Loading training data:P_00128
# (6008, 3592)
# howbig 194
# x_start [0, 103, 105, 4325, 4329]
# x_length [102, 1, 4219, 2, 134]
# y_start [0, 1867, 1870, 1874, 1887, 1891, 1895, 1930, 1978, 1980]
# y_length [1865, 2, 3, 12, 3, 3, 34, 47, 1, 810]
# start[p] 105
# start[p]+find[p] 4324
# starty[py] 0
# starty[py]+findy[py] 1865
# 3
# save3
# Loading training data:P_00133
# (4672, 2360)
# howbig 193
# x_start [0, 4436]
# x_length [4435, 78]
# y_start [0]
# y_length [2359]
# start[p] 0
# start[p]+find[p] 4435
# starty[py] 0
# starty[py]+findy[py] 2359
# 1
# save1
# Loading training data:P_00133
# (4672, 2488)
# howbig 116
# x_start [0]
# x_length [4671]
# y_start [0]
# y_length [2487]
# start[p] 0
# start[p]+find[p] 4671
# starty[py] 0
# starty[py]+findy[py] 2487
# 1
# save1
# Loading training data:P_00134
# (6466, 3451)
# howbig 408
# x_start [0, 5715, 5724, 5729, 5732, 5735, 5738, 5795, 5801, 5805, 5807, 5835, 5849]
# x_length [5714, 7, 4, 1, 1, 2, 56, 1, 3, 1, 27, 13, 416]
# y_start [0, 28, 32, 109, 245, 251]
# y_length [27, 3, 76, 135, 5, 2587]
# start[p] 0
# start[p]+find[p] 5714
# starty[py] 251
# starty[py]+findy[py] 2838
# 3
# save3
# Loading training data:P_00134
# (6826, 3886)
# howbig 323
# x_start [0]
# x_length [6825]
# y_start [0]
# y_length [3885]
# start[p] 0
# start[p]+find[p] 6825
# starty[py] 0
# starty[py]+findy[py] 3885
# 3
# save3
# Loading training data:P_00137
# (4776, 2568)
# howbig 196
# x_start [0, 258, 325, 346, 352, 359, 363, 759, 761, 769, 4351, 4354, 4356, 4360, 4363, 4367, 4370, 4372]
# x_length [257, 66, 19, 3, 6, 3, 395, 1, 3, 3581, 1, 1, 3, 2, 3, 2, 1, 222]
# y_start [0]
# y_length [2567]
# start[p] 769
# start[p]+find[p] 4350
# starty[py] 0
# starty[py]+findy[py] 2567
# 4
# save4
# Loading training data:P_00137
# (4704, 2776)
# howbig 144
# x_start [0]
# x_length [4703]
# y_start [0]
# y_length [2775]
# start[p] 0
# start[p]+find[p] 4703
# starty[py] 0
# starty[py]+findy[py] 2775
# 4
# save4
# Loading training data:P_00146
# (5864, 3784)
# howbig 206
# x_start [0, 54, 71, 4435, 4439, 4444]
# x_length [53, 16, 4363, 1, 2, 695]
# y_start [0, 951, 973, 980, 984, 989, 991, 994]
# y_length [950, 21, 6, 1, 3, 1, 1, 1968]
# start[p] 71
# start[p]+find[p] 4434
# starty[py] 994
# starty[py]+findy[py] 2962
# 1
# save1
# Loading training data:P_00146
# (5904, 3600)
# howbig 454
# x_start [0]
# x_length [5903]
# y_start [0, 197, 260]
# y_length [196, 62, 2019]
# start[p] 0
# start[p]+find[p] 5903
# starty[py] 260
# starty[py]+findy[py] 2279
# 1
# save1
# Loading training data:P_00148
# (4680, 2816)
# howbig 257
# x_start [0, 55, 4264]
# x_length [54, 4206, 109]
# y_start [0]
# y_length [2815]
# start[p] 55
# start[p]+find[p] 4261
# starty[py] 0
# starty[py]+findy[py] 2815
# 2
# save2
# Loading training data:P_00148
# (4632, 2728)
# howbig 282
# x_start [0]
# x_length [4631]
# y_start [0, 216, 251, 286]
# y_length [215, 34, 34, 2352]
# start[p] 0
# start[p]+find[p] 4631
# starty[py] 286
# starty[py]+findy[py] 2638
# 2
# save2
# Loading training data:P_00149
# (4728, 2656)
# howbig 252
# x_start [0, 4505]
# x_length [4504, 103]
# y_start [0]
# y_length [2655]
# start[p] 0
# start[p]+find[p] 4504
# starty[py] 0
# starty[py]+findy[py] 2655
# 1
# save1
# Loading training data:P_00149
# (5944, 3096)
# howbig 478
# x_start [0, 5014, 5019]
# x_length [5013, 4, 437]
# y_start [0]
# y_length [3095]
# start[p] 0
# start[p]+find[p] 5013
# starty[py] 0
# starty[py]+findy[py] 3095
# 1
# save1
# Loading training data:P_00160
# (4744, 2816)
# howbig 398
# x_start [0, 136, 140, 4452]
# x_length [134, 1, 4311, 100]
# y_start [0]
# y_length [2815]
# start[p] 140
# start[p]+find[p] 4451
# starty[py] 0
# starty[py]+findy[py] 2815
# 1
# save1
# Loading training data:P_00160
# (4736, 3000)
# howbig 202
# x_start [0]
# x_length [4735]
# y_start [0]
# y_length [2999]
# start[p] 0
# start[p]+find[p] 4735
# starty[py] 0
# starty[py]+findy[py] 2999
# 1
# save1
# Loading training data:P_00160
# (4672, 2896)
# howbig 292
# x_start [0, 4267]
# x_length [4265, 78]
# y_start [0]
# y_length [2895]
# start[p] 0
# start[p]+find[p] 4265
# starty[py] 0
# starty[py]+findy[py] 2895
# 1
# save1
# Loading training data:P_00160
# (4712, 2880)
# howbig 173
# x_start [0]
# x_length [4711]
# y_start [0]
# y_length [2879]
# start[p] 0
# start[p]+find[p] 4711
# starty[py] 0
# starty[py]+findy[py] 2879
# 1
# save1
# Loading training data:P_00166
# (6481, 3346)
# howbig 292
# x_start [0]
# x_length [6480]
# y_start [0]
# y_length [3345]
# start[p] 0
# start[p]+find[p] 6480
# starty[py] 0
# starty[py]+findy[py] 3345
# 2
# save2
# Loading training data:P_00166
# (6016, 3241)
# howbig 473
# x_start [0]
# x_length [6015]
# y_start [0]
# y_length [3240]
# start[p] 0
# start[p]+find[p] 6015
# starty[py] 0
# starty[py]+findy[py] 3240
# 2
# save2
# Loading training data:P_00169
# (4592, 2872)
# howbig 427
# x_start [0]
# x_length [4591]
# y_start [0, 123, 125, 450, 525, 529, 576]
# y_length [122, 1, 324, 74, 3, 46, 1531]
# start[p] 0
# start[p]+find[p] 4591
# starty[py] 576
# starty[py]+findy[py] 2107
# 4
# save4
# Loading training data:P_00172
# (4516, 2386)
# howbig 307
# x_start [0]
# x_length [4431]
# y_start [0]
# y_length [1737]
# start[p] 0
# start[p]+find[p] 4431
# starty[py] 0
# starty[py]+findy[py] 1737
# 4
# save4
# Loading training data:P_00172
# (5236, 2521)
# howbig 328
# x_start [0]
# x_length [5235]
# y_start [0, 125, 128, 130, 144]
# y_length [122, 2, 1, 11, 1882]
# start[p] 0
# start[p]+find[p] 5235
# starty[py] 144
# starty[py]+findy[py] 2026
# 4
# save4
# Loading training data:P_00174
# (4656, 2768)
# howbig 325
# x_start [0, 43, 382, 393, 3329]
# x_length [42, 338, 10, 2935, 79]
# y_start [0]
# y_length [2767]
# start[p] 393
# start[p]+find[p] 3328
# starty[py] 0
# starty[py]+findy[py] 2767
# 1
# save1
# Loading training data:P_00174
# (4664, 2616)
# howbig 221
# x_start [0]
# x_length [4663]
# y_start [0]
# y_length [2615]
# start[p] 0
# start[p]+find[p] 4663
# starty[py] 0
# starty[py]+findy[py] 2615
# 1
# save1
# Loading training data:P_00175
# (4528, 2976)
# howbig 216
# x_start [0]
# x_length [4527]
# y_start [0, 240, 245, 513]
# y_length [239, 4, 267, 1184]
# start[p] 0
# start[p]+find[p] 4527
# starty[py] 513
# starty[py]+findy[py] 1697
# 4
# save4
# Loading training data:P_00175
# (4528, 2960)
# howbig 120
# x_start [0]
# x_length [4527]
# y_start [0, 430, 432, 434, 733]
# y_length [427, 1, 1, 298, 1318]
# start[p] 0
# start[p]+find[p] 4527
# starty[py] 733
# starty[py]+findy[py] 2051
# 4
# save4
# Loading training data:P_00187
# (4728, 2744)
# howbig 231
# x_start [0]
# x_length [4727]
# y_start [0]
# y_length [2743]
# start[p] 0
# start[p]+find[p] 4727
# starty[py] 0
# starty[py]+findy[py] 2743
# 2
# save2
# Loading training data:P_00187
# (4720, 2736)
# howbig 246
# x_start [0]
# x_length [4719]
# y_start [0]
# y_length [2735]
# start[p] 0
# start[p]+find[p] 4719
# starty[py] 0
# starty[py]+findy[py] 2735
# 2
# save2
# Loading training data:P_00190
# (6871, 4216)
# howbig 104
# x_start [0]
# x_length [6870]
# y_start [0]
# y_length [4215]
# start[p] 0
# start[p]+find[p] 6870
# starty[py] 0
# starty[py]+findy[py] 4215
# 4
# save4
# Loading training data:P_00199
# (5824, 3808)
# howbig 129
# x_start [0, 121]
# x_length [120, 5387]
# y_start [0]
# y_length [3807]
# start[p] 121
# start[p]+find[p] 5508
# starty[py] 0
# starty[py]+findy[py] 3807
# 1
# save1
# Loading training data:P_00199
# (5528, 3920)
# howbig 247
# x_start [0, 5074]
# x_length [5073, 37]
# y_start [0, 3725]
# y_length [3724, 27]
# start[p] 0
# start[p]+find[p] 5073
# starty[py] 0
# starty[py]+findy[py] 3724
# 1
# save1
# Loading training data:P_00205
# (5832, 3824)
# howbig 447
# x_start [0, 338, 342, 345, 347]
# x_length [337, 3, 1, 1, 5353]
# y_start [0]
# y_length [3823]
# start[p] 347
# start[p]+find[p] 5700
# starty[py] 0
# starty[py]+findy[py] 3823
# 2
# save2
# Loading training data:P_00205
# (5880, 3776)
# howbig 113
# x_start [0]
# x_length [5879]
# y_start [0]
# y_length [3775]
# start[p] 0
# start[p]+find[p] 5879
# starty[py] 0
# starty[py]+findy[py] 3775
# 2
# save2
# Loading training data:P_00206
# (5856, 3736)
# howbig 298
# x_start [0, 4381]
# x_length [4380, 24]
# y_start [0, 3, 142, 308, 345, 377]
# y_length [1, 138, 165, 36, 30, 1339]
# start[p] 0
# start[p]+find[p] 4380
# starty[py] 377
# starty[py]+findy[py] 1716
# 3
# save3
# Loading training data:P_00207
# (4728, 2304)
# howbig 156
# x_start [0]
# x_length [4727]
# y_start [0]
# y_length [2303]
# start[p] 0
# start[p]+find[p] 4727
# starty[py] 0
# starty[py]+findy[py] 2303
# 1
# save1
# Loading training data:P_00207
# (4728, 2464)
# howbig 427
# x_start [0, 4242]
# x_length [4240, 65]
# y_start [0]
# y_length [2463]
# start[p] 0
# start[p]+find[p] 4240
# starty[py] 0
# starty[py]+findy[py] 2463
# 1
# save1
# Loading training data:P_00208
# (5720, 4136)
# howbig 119
# x_start [0]
# x_length [5719]
# y_start [0, 406, 561]
# y_length [405, 154, 2523]
# start[p] 0
# start[p]+find[p] 5719
# starty[py] 561
# starty[py]+findy[py] 3084
# 3
# save3
# Loading training data:P_00215
# (4592, 2912)
# howbig 493
# x_start [0, 44, 171, 3835]
# x_length [43, 126, 3663, 216]
# y_start [0, 488]
# y_length [487, 1459]
# start[p] 171
# start[p]+find[p] 3834
# starty[py] 488
# starty[py]+findy[py] 1947
# 3
# save3
# Loading training data:P_00217
# (4616, 3104)
# howbig 185
# x_start [0]
# x_length [4615]
# y_start [0, 1692, 1732, 1734, 1744, 1764, 1770, 1793, 2009]
# y_length [1691, 39, 1, 9, 19, 5, 22, 215, 106]
# start[p] 0
# start[p]+find[p] 4615
# starty[py] 0
# starty[py]+findy[py] 1691
# 3
# save3
# Loading training data:P_00218
# (6421, 2926)
# howbig 388
# x_start [0]
# x_length [6420]
# y_start [0]
# y_length [2925]
# start[p] 0
# start[p]+find[p] 6420
# starty[py] 0
# starty[py]+findy[py] 2925
# 3
# save3
# Loading training data:P_00218
# (6676, 3091)
# howbig 299
# x_start [0]
# x_length [6675]
# y_start [0]
# y_length [3090]
# start[p] 0
# start[p]+find[p] 6675
# starty[py] 0
# starty[py]+findy[py] 3090
# 3
# save3
# Loading training data:P_00219
# (4640, 3048)
# howbig 423
# x_start [0, 26, 29, 3909]
# x_length [25, 2, 3879, 131]
# y_start [0, 38]
# y_length [37, 1553]
# start[p] 29
# start[p]+find[p] 3908
# starty[py] 38
# starty[py]+findy[py] 1591
# 3
# save3
# Loading training data:P_00221
# (5491, 3091)
# howbig 370
# x_start [0]
# x_length [5490]
# y_start [0]
# y_length [3090]
# start[p] 0
# start[p]+find[p] 5490
# starty[py] 0
# starty[py]+findy[py] 3090
# 2
# save2
# Loading training data:P_00224
# (4744, 2576)
# howbig 187
# x_start [0]
# x_length [4743]
# y_start [0]
# y_length [2575]
# start[p] 0
# start[p]+find[p] 4743
# starty[py] 0
# starty[py]+findy[py] 2575
# 3
# save3
# Loading training data:P_00224
# (4760, 2392)
# howbig 408
# x_start [0]
# x_length [4759]
# y_start [0]
# y_length [2391]
# start[p] 0
# start[p]+find[p] 4759
# starty[py] 0
# starty[py]+findy[py] 2391
# 3
# save3
# Loading training data:P_00224
# (4776, 2608)
# howbig 136
# x_start [0]
# x_length [4775]
# y_start [0]
# y_length [2607]
# start[p] 0
# start[p]+find[p] 4775
# starty[py] 0
# starty[py]+findy[py] 2607
# 3
# save3
# Loading training data:P_00224
# (4736, 2760)
# howbig 491
# x_start [0, 3933]
# x_length [3932, 88]
# y_start [0]
# y_length [2759]
# start[p] 0
# start[p]+find[p] 3932
# starty[py] 0
# starty[py]+findy[py] 2759
# 3
# save3
# Loading training data:P_00225
# (6661, 3466)
# howbig 405
# x_start [0, 512, 520]
# x_length [511, 7, 5928]
# y_start [0]
# y_length [3465]
# start[p] 520
# start[p]+find[p] 6448
# starty[py] 0
# starty[py]+findy[py] 3465
# 1
# save1
# Loading training data:P_00225
# (6301, 3736)
# howbig 160
# x_start [0]
# x_length [6300]
# y_start [0, 3169, 3174, 3210, 3532]
# y_length [3168, 4, 35, 321, 3]
# start[p] 0
# start[p]+find[p] 6300
# starty[py] 0
# starty[py]+findy[py] 3168
# 1
# save1
# Loading training data:P_00226
# (5928, 4056)
# howbig 223
# x_start [0, 106, 109]
# x_length [105, 2, 4858]
# y_start [0, 2092]
# y_length [2091, 460]
# start[p] 109
# start[p]+find[p] 4967
# starty[py] 0
# starty[py]+findy[py] 2091
# 4
# save4
# Loading training data:P_00226
# (5896, 4072)
# howbig 324
# x_start [0, 4851, 4855]
# x_length [4850, 3, 98]
# y_start [0, 2295]
# y_length [2294, 87]
# start[p] 0
# start[p]+find[p] 4850
# starty[py] 0
# starty[py]+findy[py] 2294
# 4
# save4
# Loading training data:P_00229
# (4576, 2968)
# howbig 149
# x_start [0]
# x_length [4575]
# y_start [0, 1450, 1560, 1852]
# y_length [1448, 109, 291, 53]
# start[p] 0
# start[p]+find[p] 4575
# starty[py] 0
# starty[py]+findy[py] 1448
# 2
# save2
# Loading training data:P_00229
# (4584, 2952)
# howbig 304
# x_start [0]
# x_length [4583]
# y_start [0, 1644, 1650, 1857]
# y_length [1643, 5, 206, 149]
# start[p] 0
# start[p]+find[p] 4583
# starty[py] 0
# starty[py]+findy[py] 1643
# 2
# save2
# Loading training data:P_00231
# (4568, 2912)
# howbig 444
# x_start [0, 90]
# x_length [87, 3747]
# y_start [0, 1235, 1332]
# y_length [1234, 96, 362]
# start[p] 90
# start[p]+find[p] 3837
# starty[py] 0
# starty[py]+findy[py] 1234
# 3
# save3
# Loading training data:P_00231
# (4592, 2920)
# howbig 202
# x_start [0]
# x_length [4591]
# y_start [0, 1250, 1352]
# y_length [1249, 101, 449]
# start[p] 0
# start[p]+find[p] 4591
# starty[py] 0
# starty[py]+findy[py] 1249
# 3
# save3
# Loading training data:P_00234
# (5146, 2221)
# howbig 463
# x_start [0]
# x_length [5145]
# y_start [0]
# y_length [1866]
# start[p] 0
# start[p]+find[p] 5145
# starty[py] 0
# starty[py]+findy[py] 1866
# 3
# save3
# Loading training data:P_00235
# (6691, 4156)
# howbig 154
# x_start [0]
# x_length [6226]
# y_start [0, 3567, 3899]
# y_length [3565, 331, 204]
# start[p] 0
# start[p]+find[p] 6226
# starty[py] 0
# starty[py]+findy[py] 3565
# 2
# save2
# Loading training data:P_00235
# (6436, 4006)
# howbig 300
# x_start [0]
# x_length [5852]
# y_start [0, 3437, 3456, 3459, 3468, 3475, 3484, 3494, 3506, 3509, 3512, 3516, 3519, 3526, 3530, 3532, 3542, 3547, 3551, 3553, 3560, 3575, 3579, 3584, 3595, 3600, 3608, 3611, 3614, 3617, 3704, 3709, 3758, 3765, 3778, 3791, 3794, 3809, 3817, 3826, 3833, 3837, 3843, 3854, 3877, 3891, 3893, 3898, 3917]
# y_length [3436, 18, 2, 8, 4, 8, 9, 11, 2, 2, 2, 2, 6, 3, 1, 9, 4, 2, 1, 6, 14, 2, 4, 10, 4, 6, 2, 2, 2, 86, 4, 48, 6, 12, 12, 2, 14, 7, 8, 6, 3, 4, 10, 22, 13, 1, 4, 18, 13]
# start[p] 0
# start[p]+find[p] 5852
# starty[py] 0
# starty[py]+findy[py] 3436
# 2
# save2
# Loading training data:P_00236
# (4712, 2568)
# howbig 478
# x_start [0, 3799]
# x_length [3798, 69]
# y_start [0]
# y_length [2567]
# start[p] 0
# start[p]+find[p] 3798
# starty[py] 0
# starty[py]+findy[py] 2567
# 2
# save2
# Loading training data:P_00239
# (4760, 2512)
# howbig 137
# x_start [0]
# x_length [4759]
# y_start [0]
# y_length [2511]
# start[p] 0
# start[p]+find[p] 4759
# starty[py] 0
# starty[py]+findy[py] 2511
# 2
# save2
# Loading training data:P_00239
# (4688, 2608)
# howbig 403
# x_start [0, 4506]
# x_length [4505, 73]
# y_start [0]
# y_length [2607]
# start[p] 0
# start[p]+find[p] 4505
# starty[py] 0
# starty[py]+findy[py] 2607
# 2
# save2
# Loading training data:P_00240
# (4704, 2768)
# howbig 474
# x_start [0, 4165]
# x_length [4164, 89]
# y_start [0]
# y_length [2767]
# start[p] 0
# start[p]+find[p] 4164
# starty[py] 0
# starty[py]+findy[py] 2767
# 2
# save2
# Loading training data:P_00240
# (4736, 2824)
# howbig 389
# x_start [0, 3723]
# x_length [3722, 121]
# y_start [0]
# y_length [2823]
# start[p] 0
# start[p]+find[p] 3722
# starty[py] 0
# starty[py]+findy[py] 2823
# 2
# save2
# Loading training data:P_00241
# (6024, 4208)
# howbig 450
# x_start [0]
# x_length [6023]
# y_start [0]
# y_length [4207]
# start[p] 0
# start[p]+find[p] 6023
# starty[py] 0
# starty[py]+findy[py] 4207
# 2
# save2
# Loading training data:P_00241
# (6048, 4216)
# howbig 311
# x_start [0]
# x_length [6047]
# y_start [0]
# y_length [4215]
# start[p] 0
# start[p]+find[p] 6047
# starty[py] 0
# starty[py]+findy[py] 4215
# 2
# save2
# Loading training data:P_00242
# (4600, 2760)
# howbig 123
# x_start [0]
# x_length [4599]
# y_start [0, 56, 71]
# y_length [55, 14, 2049]
# start[p] 0
# start[p]+find[p] 4599
# starty[py] 71
# starty[py]+findy[py] 2120
# 2
# save2
# Loading training data:P_00242
# (4584, 2848)
# howbig 320
# x_start [0]
# x_length [4583]
# y_start [0, 140, 230, 260]
# y_length [139, 89, 29, 2183]
# start[p] 0
# start[p]+find[p] 4583
# starty[py] 260
# starty[py]+findy[py] 2443
# 2
# save2
# Loading training data:P_00247
# (4400, 2864)
# howbig 114
# x_start [0]
# x_length [4399]
# y_start [0]
# y_length [2863]
# start[p] 0
# start[p]+find[p] 4399
# starty[py] 0
# starty[py]+findy[py] 2863
# 3
# save3
# Loading training data:P_00247
# (4384, 2760)
# howbig 109
# x_start [0]
# x_length [4383]
# y_start [0]
# y_length [2759]
# start[p] 0
# start[p]+find[p] 4383
# starty[py] 0
# starty[py]+findy[py] 2759
# 3
# save3
# Loading training data:P_00248
# (6511, 4801)
# howbig 261
# x_start [0]
# x_length [6510]
# y_start [0, 524, 528, 533, 557]
# y_length [523, 1, 4, 22, 4073]
# start[p] 0
# start[p]+find[p] 6510
# starty[py] 557
# starty[py]+findy[py] 4630
# 2
# save2
# Loading training data:P_00254
# (4760, 2816)
# howbig 459
# x_start [0, 4371]
# x_length [4370, 105]
# y_start [0]
# y_length [2331]
# start[p] 0
# start[p]+find[p] 4370
# starty[py] 0
# starty[py]+findy[py] 2331
# 3
# save3
# Loading training data:P_00254
# (5856, 3672)
# howbig 176
# x_start [0, 4759]
# x_length [4758, 105]
# y_start [0]
# y_length [3671]
# start[p] 0
# start[p]+find[p] 4758
# starty[py] 0
# starty[py]+findy[py] 3671
# 3
# save3
# Loading training data:P_00259
# (4608, 2624)
# howbig 332
# x_start [0, 53, 3566]
# x_length [52, 3512, 21]
# y_start [0, 250]
# y_length [249, 1351]
# start[p] 53
# start[p]+find[p] 3565
# starty[py] 250
# starty[py]+findy[py] 1601
# 1
# save1
# Loading training data:P_00259
# (4664, 2800)
# howbig 303
# x_start [0]
# x_length [4663]
# y_start [0]
# y_length [2799]
# start[p] 0
# start[p]+find[p] 4663
# starty[py] 0
# starty[py]+findy[py] 2799
# 1
# save1
# Loading training data:P_00264
# (4176, 2776)
# howbig 320
# x_start [0]
# x_length [4175]
# y_start [0, 2076, 2176, 2178]
# y_length [2075, 99, 1, 3]
# start[p] 0
# start[p]+find[p] 4175
# starty[py] 0
# starty[py]+findy[py] 2075
# 2
# save2
# Loading training data:P_00264
# (4456, 2888)
# howbig 291
# x_start [0]
# x_length [4455]
# y_start [0, 2214, 2275, 2388, 2413]
# y_length [2213, 60, 112, 24, 101]
# start[p] 0
# start[p]+find[p] 4455
# starty[py] 0
# starty[py]+findy[py] 2213
# 2
# save2
# Loading training data:P_00265
# (5856, 3472)
# howbig 157
# x_start [0]
# x_length [5855]
# y_start [0]
# y_length [3471]
# start[p] 0
# start[p]+find[p] 5855
# starty[py] 0
# starty[py]+findy[py] 3471
# 1
# save1
# Loading training data:P_00265
# (5832, 3664)
# howbig 169
# x_start [0]
# x_length [5831]
# y_start [0, 93, 110, 564]
# y_length [91, 13, 453, 2628]
# start[p] 0
# start[p]+find[p] 5831
# starty[py] 564
# starty[py]+findy[py] 3192
# 1
# save1
# Loading training data:P_00273
# (6871, 3841)
# howbig 110
# x_start [0]
# x_length [6870]
# y_start [0]
# y_length [3840]
# start[p] 0
# start[p]+find[p] 6870
# starty[py] 0
# starty[py]+findy[py] 3840
# 2
# save2
# Loading training data:P_00279
# (5386, 3691)
# howbig 114
# x_start [0]
# x_length [5385]
# y_start [0]
# y_length [3470]
# start[p] 0
# start[p]+find[p] 5385
# starty[py] 0
# starty[py]+findy[py] 3470
# 3
# save3
# Loading training data:P_00281
# (6256, 3166)
# howbig 185
# x_start [0]
# x_length [6255]
# y_start [0]
# y_length [3165]
# start[p] 0
# start[p]+find[p] 6255
# starty[py] 0
# starty[py]+findy[py] 3165
# 3
# save3
# Loading training data:P_00283
# (5791, 2716)
# howbig 346
# x_start [1, 5025]
# x_length [5023, 2]
# y_start [0]
# y_length [2136]
# start[p] 1
# start[p]+find[p] 5024
# starty[py] 0
# starty[py]+findy[py] 2136
# 3
# save3
# Loading training data:P_00283
# (6316, 2881)
# howbig 351
# x_start [0, 8, 14, 19]
# x_length [7, 5, 1, 5777]
# y_start [0, 2775, 2787, 2789]
# y_length [2774, 11, 1, 3]
# start[p] 19
# start[p]+find[p] 5796
# starty[py] 0
# starty[py]+findy[py] 2774
# 3
# save3
# Loading training data:P_00287
# (4704, 2784)
# howbig 113
# x_start [0]
# x_length [4703]
# y_start [0]
# y_length [2783]
# start[p] 0
# start[p]+find[p] 4703
# starty[py] 0
# starty[py]+findy[py] 2783
# 2
# save2
# Loading training data:P_00287
# (4752, 2792)
# howbig 249
# x_start [0]
# x_length [4751]
# y_start [0]
# y_length [2791]
# start[p] 0
# start[p]+find[p] 4751
# starty[py] 0
# starty[py]+findy[py] 2791
# 2
# save2
# Loading training data:P_00289
# (5356, 2806)
# howbig 213
# x_start [0]
# x_length [5355]
# y_start [0, 651]
# y_length [650, 1982]
# start[p] 0
# start[p]+find[p] 5355
# starty[py] 651
# starty[py]+findy[py] 2633
# 3
# save3
# Loading training data:P_00289
# (5491, 2761)
# howbig 478
# x_start [0]
# x_length [5490]
# y_start [0]
# y_length [2760]
# start[p] 0
# start[p]+find[p] 5490
# starty[py] 0
# starty[py]+findy[py] 2760
# 3
# save3
# Loading training data:P_00294
# (4560, 2864)
# howbig 450
# x_start [0, 53, 4015, 4035]
# x_length [52, 3961, 19, 2]
# y_start [0, 1739]
# y_length [1738, 482]
# start[p] 53
# start[p]+find[p] 4014
# starty[py] 0
# starty[py]+findy[py] 1738
# 2
# save2
# Loading training data:P_00294
# (4512, 2912)
# howbig 199
# x_start [0]
# x_length [4511]
# y_start [0, 1866, 1971, 2239]
# y_length [1865, 104, 267, 187]
# start[p] 0
# start[p]+find[p] 4511
# starty[py] 0
# starty[py]+findy[py] 1865
# 2
# save2
# Loading training data:P_00298
# (4560, 2928)
# howbig 260
# x_start [0]
# x_length [4559]
# y_start [0, 1839]
# y_length [1837, 432]
# start[p] 0
# start[p]+find[p] 4559
# starty[py] 0
# starty[py]+findy[py] 1837
# 3
# save3
# Loading training data:P_00298
# (4528, 2920)
# howbig 107
# x_start [0]
# x_length [4527]
# y_start [0, 2264]
# y_length [2263, 610]
# start[p] 0
# start[p]+find[p] 4527
# starty[py] 0
# starty[py]+findy[py] 2263
# 3
# save3
# Loading training data:P_00303
# (4520, 2888)
# howbig 149
# x_start [0]
# x_length [4519]
# y_start [0, 1342, 1463]
# y_length [1341, 120, 191]
# start[p] 0
# start[p]+find[p] 4519
# starty[py] 0
# starty[py]+findy[py] 1341
# 2
# save2
# Loading training data:P_00303
# (4552, 2976)
# howbig 418
# x_start [0]
# x_length [4551]
# y_start [0, 1597]
# y_length [1596, 340]
# start[p] 0
# start[p]+find[p] 4551
# starty[py] 0
# starty[py]+findy[py] 1596
# 2
# save2
# Loading training data:P_00303
# (4592, 2944)
# howbig 105
# x_start [0]
# x_length [4591]
# y_start [0, 478]
# y_length [477, 1136]
# start[p] 0
# start[p]+find[p] 4591
# starty[py] 478
# starty[py]+findy[py] 1614
# 2
# save2
# Loading training data:P_00303
# (4600, 2848)
# howbig 204
# x_start [0]
# x_length [4599]
# y_start [0, 638]
# y_length [637, 1307]
# start[p] 0
# start[p]+find[p] 4599
# starty[py] 638
# starty[py]+findy[py] 1945
# 2
# save2
# Loading training data:P_00304
# (5221, 3391)
# howbig 196
# x_start [0]
# x_length [5220]
# y_start [0, 2653]
# y_length [2652, 385]
# start[p] 0
# start[p]+find[p] 5220
# starty[py] 0
# starty[py]+findy[py] 2652
# 3
# save3
# Loading training data:P_00309
# (4552, 2968)
# howbig 351
# x_start [0]
# x_length [4551]
# y_start [0, 1564, 1643]
# y_length [1563, 78, 61]
# start[p] 0
# start[p]+find[p] 4551
# starty[py] 0
# starty[py]+findy[py] 1563
# 2
# save2
# Loading training data:P_00309
# (4584, 2744)
# howbig 445
# x_start [0, 4178, 4182, 4186]
# x_length [4175, 1, 1, 318]
# y_start [0, 1635, 1803, 1960]
# y_length [1634, 167, 156, 10]
# start[p] 0
# start[p]+find[p] 4175
# starty[py] 0
# starty[py]+findy[py] 1634
# 2
# save2
# Loading training data:P_00313
# (4846, 2206)
# howbig 325
# x_start [0]
# x_length [4845]
# y_start [0, 1615, 1639]
# y_length [1614, 23, 76]
# start[p] 0
# start[p]+find[p] 4845
# starty[py] 0
# starty[py]+findy[py] 1614
# 2
# save2
# Loading training data:P_00313
# (4906, 2221)
# howbig 487
# x_start [0, 4450, 4454]
# x_length [4448, 3, 3]
# y_start [0]
# y_length [2220]
# start[p] 0
# start[p]+find[p] 4448
# starty[py] 0
# starty[py]+findy[py] 2220
# 2
# save2
# Loading training data:P_00314
# (4640, 2752)
# howbig 314
# x_start [0]
# x_length [4639]
# y_start [0]
# y_length [2751]
# start[p] 0
# start[p]+find[p] 4639
# starty[py] 0
# starty[py]+findy[py] 2751
# 1
# save1
# Loading training data:P_00314
# (4680, 2736)
# howbig 478
# x_start [0, 4257]
# x_length [4256, 81]
# y_start [0]
# y_length [2735]
# start[p] 0
# start[p]+find[p] 4256
# starty[py] 0
# starty[py]+findy[py] 2735
# 1
# save1
# Loading training data:P_00317
# (5761, 3166)
# howbig 217
# x_start [0]
# x_length [5760]
# y_start [0, 2831, 2836, 2841, 2858, 2861, 2903, 2910, 2913]
# y_length [2830, 4, 4, 16, 2, 41, 5, 2, 112]
# start[p] 0
# start[p]+find[p] 5760
# starty[py] 0
# starty[py]+findy[py] 2830
# 2
# save2
# Loading training data:P_00319
# (5491, 3166)
# howbig 329
# x_start [0]
# x_length [5490]
# y_start [0]
# y_length [3165]
# start[p] 0
# start[p]+find[p] 5490
# starty[py] 0
# starty[py]+findy[py] 3165
# 1
# save1
# Loading training data:P_00319
# (5401, 3256)
# howbig 454
# x_start [0]
# x_length [5400]
# y_start [0]
# y_length [3255]
# start[p] 0
# start[p]+find[p] 5400
# starty[py] 0
# starty[py]+findy[py] 3255
# 1
# save1
# Loading training data:P_00320
# (4664, 3096)
# howbig 101
# x_start [0]
# x_length [4663]
# y_start [0]
# y_length [3095]
# start[p] 0
# start[p]+find[p] 4663
# starty[py] 0
# starty[py]+findy[py] 3095
# 3
# save3
# Loading training data:P_00320
# (4640, 3080)
# howbig 226
# x_start [0, 4092, 4094]
# x_length [4091, 1, 226]
# y_start [0, 1908, 1911, 1913, 2189, 2293, 2399]
# y_length [1907, 2, 1, 275, 103, 105, 5]
# start[p] 0
# start[p]+find[p] 4091
# starty[py] 0
# starty[py]+findy[py] 1907
# 3
# save3
# Loading training data:P_00328
# (5928, 4056)
# howbig 319
# x_start [0]
# x_length [5927]
# y_start [0, 2380, 2432, 2493]
# y_length [2379, 51, 60, 558]
# start[p] 0
# start[p]+find[p] 5927
# starty[py] 0
# starty[py]+findy[py] 2379
# 3
# save3
# Loading training data:P_00328
# (5920, 4056)
# howbig 435
# x_start [0]
# x_length [5919]
# y_start [0, 966, 981, 985]
# y_length [965, 14, 3, 2283]
# start[p] 0
# start[p]+find[p] 5919
# starty[py] 985
# starty[py]+findy[py] 3268
# 3
# save3
# Loading training data:P_00328
# (5928, 4056)
# howbig 160
# x_start [0]
# x_length [5927]
# y_start [0]
# y_length [4055]
# start[p] 0
# start[p]+find[p] 5927
# starty[py] 0
# starty[py]+findy[py] 4055
# 3
# save3
# Loading training data:P_00330
# (4516, 2626)
# howbig 100
# x_start [0]
# x_length [4515]
# y_start [0]
# y_length [2625]
# start[p] 0
# start[p]+find[p] 4515
# starty[py] 0
# starty[py]+findy[py] 2625
# 2
# save2
# Loading training data:P_00330
# (4696, 2671)
# howbig 347
# x_start [0]
# x_length [4695]
# y_start [0, 29, 136]
# y_length [28, 106, 2461]
# start[p] 0
# start[p]+find[p] 4695
# starty[py] 136
# starty[py]+findy[py] 2597
# 2
# save2
# Loading training data:P_00332
# (4592, 2640)
# howbig 301
# x_start [0, 4215]
# x_length [4213, 74]
# y_start [0]
# y_length [2639]
# start[p] 0
# start[p]+find[p] 4213
# starty[py] 0
# starty[py]+findy[py] 2639
# 1
# save1
# Loading training data:P_00332
# (4712, 2752)
# howbig 208
# x_start [0]
# x_length [4711]
# y_start [0]
# y_length [2751]
# start[p] 0
# start[p]+find[p] 4711
# starty[py] 0
# starty[py]+findy[py] 2751
# 1
# save1
# Loading training data:P_00332
# (4712, 2696)
# howbig 481
# x_start [0, 58, 4244]
# x_length [57, 4185, 92]
# y_start [0]
# y_length [2695]
# start[p] 58
# start[p]+find[p] 4243
# starty[py] 0
# starty[py]+findy[py] 2695
# 1
# save1
# Loading training data:P_00332
# (4704, 2696)
# howbig 227
# x_start [0]
# x_length [4703]
# y_start [0]
# y_length [2695]
# start[p] 0
# start[p]+find[p] 4703
# starty[py] 0
# starty[py]+findy[py] 2695
# 1
# save1
# Loading training data:P_00333
# (5251, 2251)
# howbig 384
# x_start [0, 36]
# x_length [34, 4353]
# y_start [0]
# y_length [1477]
# start[p] 36
# start[p]+find[p] 4389
# starty[py] 0
# starty[py]+findy[py] 1477
# 2
# save2
# Loading training data:P_00333
# (5101, 2581)
# howbig 497
# x_start [0, 4521]
# x_length [4520, 3]
# y_start [0]
# y_length [1795]
# start[p] 0
# start[p]+find[p] 4520
# starty[py] 0
# starty[py]+findy[py] 1795
# 2
# save2
# Loading training data:P_00334
# (4680, 2664)
# howbig 229
# x_start [0, 4052]
# x_length [4051, 579]
# y_start [0]
# y_length [2663]
# start[p] 0
# start[p]+find[p] 4051
# starty[py] 0
# starty[py]+findy[py] 2663
# 3
# save3
# Loading training data:P_00335
# (5986, 2461)
# howbig 401
# x_start [0]
# x_length [5985]
# y_start [0]
# y_length [1644]
# start[p] 0
# start[p]+find[p] 5985
# starty[py] 0
# starty[py]+findy[py] 1644
# 2
# save2
# Loading training data:P_00342
# (5600, 3672)
# howbig 308
# x_start [0, 2, 4334]
# x_length [1, 4322, 6]
# y_start [0, 194]
# y_length [193, 2476]
# start[p] 2
# start[p]+find[p] 4324
# starty[py] 194
# starty[py]+findy[py] 2670
# 1
# save1
# Loading training data:P_00342
# (5728, 3712)
# howbig 354
# x_start [0, 5306, 5311]
# x_length [5304, 4, 310]
# y_start [0, 66, 200]
# y_length [65, 133, 2916]
# start[p] 0
# start[p]+find[p] 5304
# starty[py] 200
# starty[py]+findy[py] 3116
# 1
# save1
# Loading training data:P_00348
# (5341, 2251)
# howbig 209
# x_start [0]
# x_length [5340]
# y_start [0]
# y_length [2250]
# start[p] 0
# start[p]+find[p] 5340
# starty[py] 0
# starty[py]+findy[py] 2250
# 4
# save4
# Loading training data:P_00348
# (5491, 2701)
# howbig 111
# x_start [0]
# x_length [5490]
# y_start [0]
# y_length [2700]
# start[p] 0
# start[p]+find[p] 5490
# starty[py] 0
# starty[py]+findy[py] 2700
# 4
# save4
# Loading training data:P_00351
# (5520, 3928)
# howbig 436
# x_start [1, 5200]
# x_length [5198, 6]
# y_start [0]
# y_length [2788]
# start[p] 1
# start[p]+find[p] 5199
# starty[py] 0
# starty[py]+findy[py] 2788
# 2
# save2
# Loading training data:P_00351
# (5640, 3904)
# howbig 123
# x_start [0]
# x_length [5639]
# y_start [0]
# y_length [3130]
# start[p] 0
# start[p]+find[p] 5639
# starty[py] 0
# starty[py]+findy[py] 3130
# 2
# save2
# Loading training data:P_00354
# (5881, 3361)
# howbig 190
# x_start [0, 33, 355, 358, 360]
# x_length [31, 321, 1, 1, 5059]
# y_start [0, 151]
# y_length [150, 2520]
# start[p] 360
# start[p]+find[p] 5419
# starty[py] 151
# starty[py]+findy[py] 2671
# 2
# save2
# Loading training data:P_00354
# (6871, 3466)
# howbig 306
# x_start [0]
# x_length [6870]
# y_start [0]
# y_length [3465]
# start[p] 0
# start[p]+find[p] 6870
# starty[py] 0
# starty[py]+findy[py] 3465
# 2
# save2
# Loading training data:P_00356
# (6451, 3061)
# howbig 232
# x_start [0]
# x_length [6450]
# y_start [0, 105]
# y_length [104, 2555]
# start[p] 0
# start[p]+find[p] 6450
# starty[py] 105
# starty[py]+findy[py] 2660
# 2
# save2
# Loading training data:P_00361
# (5176, 2251)
# howbig 109
# x_start [0, 3739, 3749, 3755, 3757]
# x_length [3738, 8, 4, 1, 1]
# y_start [0, 226]
# y_length [225, 1294]
# start[p] 0
# start[p]+find[p] 3738
# starty[py] 226
# starty[py]+findy[py] 1520
# 4
# save4
# Loading training data:P_00363
# (4728, 2536)
# howbig 187
# x_start [0]
# x_length [4727]
# y_start [0]
# y_length [2535]
# start[p] 0
# start[p]+find[p] 4727
# starty[py] 0
# starty[py]+findy[py] 2535
# 2
# save2
# Loading training data:P_00363
# (4736, 2712)
# howbig 430
# x_start [0]
# x_length [4735]
# y_start [0]
# y_length [2711]
# start[p] 0
# start[p]+find[p] 4735
# starty[py] 0
# starty[py]+findy[py] 2711
# 2
# save2
# Loading training data:P_00366
# (6151, 3496)
# howbig 159
# x_start [0]
# x_length [6150]
# y_start [0, 2653, 2656]
# y_length [2652, 2, 370]
# start[p] 0
# start[p]+find[p] 6150
# starty[py] 0
# starty[py]+findy[py] 2652
# 2
# save2
# Loading training data:P_00366
# (6706, 3631)
# howbig 392
# x_start [0]
# x_length [6705]
# y_start [0]
# y_length [3630]
# start[p] 0
# start[p]+find[p] 6705
# starty[py] 0
# starty[py]+findy[py] 3630
# 2
# save2
# Loading training data:P_00370
# (5371, 2881)
# howbig 148
# x_start [0]
# x_length [5370]
# y_start [0]
# y_length [2880]
# start[p] 0
# start[p]+find[p] 5370
# starty[py] 0
# starty[py]+findy[py] 2880
# 2
# save2
# Loading training data:P_00370
# (5491, 3121)
# howbig 221
# x_start [0]
# x_length [5490]
# y_start [0]
# y_length [3120]
# start[p] 0
# start[p]+find[p] 5490
# starty[py] 0
# starty[py]+findy[py] 3120
# 2
# save2
# Loading training data:P_00376
# (5648, 3856)
# howbig 209
# x_start [0]
# x_length [5647]
# y_start [0, 371, 392]
# y_length [370, 20, 2589]
# start[p] 0
# start[p]+find[p] 5647
# starty[py] 392
# starty[py]+findy[py] 2981
# 1
# save1
# Loading training data:P_00376
# (5760, 3912)
# howbig 277
# x_start [0]
# x_length [5759]
# y_start [0, 79, 315]
# y_length [78, 235, 2601]
# start[p] 0
# start[p]+find[p] 5759
# starty[py] 315
# starty[py]+findy[py] 2916
# 1
# save1
# Loading training data:P_00383
# (6871, 4366)
# howbig 310
# x_start [0]
# x_length [6870]
# y_start [0]
# y_length [4365]
# start[p] 0
# start[p]+find[p] 6870
# starty[py] 0
# starty[py]+findy[py] 4365
# 1
# save1
# Loading training data:P_00384
# (5296, 3061)
# howbig 500
# x_start [0, 3, 4713]
# x_length [2, 4709, 86]
# y_start [0]
# y_length [2445]
# start[p] 3
# start[p]+find[p] 4712
# starty[py] 0
# ...
# starty[py]+findy[py] 4007
# 3
# save3
# Loading training data:P_01408
# (5584, 4128)
# howbig 451
# x_start [0]
# x_length [5583]
# y_start [0, 2734, 2745, 2801]
# y_length [2733, 10, 55, 32]
# start[p] 0
# start[p]+find[p] 5583
# starty[py] 0
# starty[py]+findy[py] 2733
# 3
# save3
# Loading training data:P_01409
# (4624, 3136)
# howbig 198
# x_start [0]
# x_length [4623]
# y_start [0, 1883, 1989, 2176]
# y_length [1882, 105, 186, 26]
# start[p] 0
# start[p]+find[p] 4623
# starty[py] 0
# starty[py]+findy[py] 1882
# 2
# save2
# Loading training data:P_01409
# (4536, 3144)
# howbig 315
# x_start [0]
# x_length [4535]
# y_start [0, 1824, 1827, 1835, 1859, 1862, 1905, 1995, 2029, 2113]
# y_length [1822, 1, 7, 23, 1, 42, 89, 33, 83, 8]
# start[p] 0
# start[p]+find[p] 4535
# starty[py] 0
# starty[py]+findy[py] 1822
# 2
# save2
# Loading training data:P_01409
# (4696, 2904)
# howbig 283
# x_start [0, 3778, 3789, 3793, 3797, 3801, 3812, 3819, 3829, 3831, 3833]
# x_length [3776, 3, 1, 2, 2, 9, 4, 7, 1, 1, 46]
# y_start [0, 372]
# y_length [371, 1757]
# start[p] 0
# start[p]+find[p] 3776
# starty[py] 372
# starty[py]+findy[py] 2129
# 2
# save2
# Loading training data:P_01409
# (4704, 2928)
# howbig 172
# x_start [0]
# x_length [4703]
# y_start [0, 182, 184, 657]
# y_length [181, 1, 472, 1648]
# start[p] 0
# start[p]+find[p] 4703
# starty[py] 657
# starty[py]+findy[py] 2305
# 2
# save2
# Loading training data:P_01410
# (4520, 2904)
# howbig 120
# x_start [0]
# x_length [4519]
# y_start [0, 1046]
# y_length [1045, 621]
# start[p] 0
# start[p]+find[p] 4519
# starty[py] 0
# starty[py]+findy[py] 1045
# 4
# save4
# Loading training data:P_01410
# (4536, 2952)
# howbig 238
# x_start [0]
# x_length [4535]
# y_start [0, 1259, 1398]
# y_length [1258, 138, 692]
# start[p] 0
# start[p]+find[p] 4535
# starty[py] 0
# starty[py]+findy[py] 1258
# 4
# save4
# Loading training data:P_01420
# (4516, 2851)
# howbig 321
# x_start [0]
# x_length [4174]
# y_start [0, 2181]
# y_length [2180, 508]
# start[p] 0
# start[p]+find[p] 4174
# starty[py] 0
# starty[py]+findy[py] 2180
# 3
# save3
# Loading training data:P_01420
# (5431, 2926)
# howbig 120
# x_start [0]
# x_length [5430]
# y_start [0]
# y_length [2925]
# start[p] 0
# start[p]+find[p] 5430
# starty[py] 0
# starty[py]+findy[py] 2925
# 3
# save3
# Loading training data:P_01422
# (6091, 3616)
# howbig 336
# x_start [0]
# x_length [6090]
# y_start [0, 2759]
# y_length [2758, 1]
# start[p] 0
# start[p]+find[p] 6090
# starty[py] 0
# starty[py]+findy[py] 2758
# 3
# save3
# Loading training data:P_01422
# (5641, 3901)
# howbig 417
# x_start [0]
# x_length [5640]
# y_start [0]
# y_length [3206]
# start[p] 0
# start[p]+find[p] 5640
# starty[py] 0
# starty[py]+findy[py] 3206
# 3
# save3
# Loading training data:P_01424
# (5491, 2971)
# howbig 225
# x_start [0]
# x_length [5490]
# y_start [0]
# y_length [2970]
# start[p] 0
# start[p]+find[p] 5490
# starty[py] 0
# starty[py]+findy[py] 2970
# 4
# save4
# Loading training data:P_01424
# (5491, 2866)
# howbig 410
# x_start [0]
# x_length [5490]
# y_start [0]
# y_length [2865]
# start[p] 0
# start[p]+find[p] 5490
# starty[py] 0
# starty[py]+findy[py] 2865
# 4
# save4
# Loading training data:P_01435
# (4232, 3048)
# howbig 115
# x_start [0]
# x_length [4231]
# y_start [0, 145, 368, 389]
# y_length [143, 222, 20, 1237]
# start[p] 0
# start[p]+find[p] 4231
# starty[py] 389
# starty[py]+findy[py] 1626
# 4
# save4
# Loading training data:P_01435
# (4496, 3056)
# howbig 326
# x_start [0]
# x_length [4495]
# y_start [0, 129, 280]
# y_length [128, 150, 1404]
# start[p] 0
# start[p]+find[p] 4495
# starty[py] 280
# starty[py]+findy[py] 1684
# 4
# save4
# Loading training data:P_01436
# (4760, 3088)
# howbig 272
# x_start [0, 82]
# x_length [81, 4502]
# y_start [0]
# y_length [3087]
# start[p] 82
# start[p]+find[p] 4584
# starty[py] 0
# starty[py]+findy[py] 3087
# 3
# save3
# Loading training data:P_01436
# (4784, 3016)
# howbig 230
# x_start [0]
# x_length [4783]
# y_start [0]
# y_length [3015]
# start[p] 0
# start[p]+find[p] 4783
# starty[py] 0
# starty[py]+findy[py] 3015
# 3
# save3
# Loading training data:P_01437
# (4264, 2976)
# howbig 415
# x_start [0, 31]
# x_length [30, 3560]
# y_start [0]
# y_length [1934]
# start[p] 31
# start[p]+find[p] 3591
# starty[py] 0
# starty[py]+findy[py] 1934
# 4
# save4
# Loading training data:P_01437
# (4312, 3040)
# howbig 141
# x_start [0]
# x_length [4311]
# y_start [0, 2393, 2484, 2494]
# y_length [2392, 90, 9, 44]
# start[p] 0
# start[p]+find[p] 4311
# starty[py] 0
# starty[py]+findy[py] 2392
# 4
# save4
# Loading training data:P_01437
# (4352, 3008)
# howbig 371
# x_start [0]
# x_length [3987]
# y_start [0, 118, 310]
# y_length [117, 191, 2227]
# start[p] 0
# start[p]+find[p] 3987
# starty[py] 310
# starty[py]+findy[py] 2537
# 4
# save4
# Loading training data:P_01437
# (4384, 2976)
# howbig 236
# x_start [0]
# x_length [3495]
# y_start [0, 96, 249]
# y_length [95, 152, 2351]
# start[p] 0
# start[p]+find[p] 3495
# starty[py] 249
# starty[py]+findy[py] 2600
# 4
# save4
# Loading training data:P_01440
# (4488, 3040)
# howbig 135
# x_start [0]
# x_length [4487]
# y_start [0]
# y_length [1638]
# start[p] 0
# start[p]+find[p] 4487
# starty[py] 0
# starty[py]+findy[py] 1638
# 3
# save3
# Loading training data:P_01440
# (4552, 3072)
# howbig 401
# x_start [0, 3892]
# x_length [3890, 13]
# y_start [0, 1829]
# y_length [1828, 35]
# start[p] 0
# start[p]+find[p] 3890
# starty[py] 0
# starty[py]+findy[py] 1828
# 3
# save3
# Loading training data:P_01440
# (4552, 3064)
# howbig 473
# x_start [0, 139, 145, 4141, 4147]
# x_length [137, 2, 3994, 5, 156]
# y_start [0, 21, 93]
# y_length [20, 69, 1563]
# start[p] 145
# start[p]+find[p] 4139
# starty[py] 93
# starty[py]+findy[py] 1656
# 3
# save3
# Loading training data:P_01440
# (4584, 3056)
# howbig 139
# x_start [0]
# x_length [4583]
# y_start [0, 45, 219, 230, 236, 282]
# y_length [44, 173, 10, 5, 45, 1872]
# start[p] 0
# start[p]+find[p] 4583
# starty[py] 282
# starty[py]+findy[py] 2154
# 3
# save3
# Loading training data:P_01443
# (4488, 2920)
# howbig 114
# x_start [0]
# x_length [4487]
# y_start [0, 268, 625, 666]
# y_length [267, 356, 40, 1167]
# start[p] 0
# start[p]+find[p] 4487
# starty[py] 666
# starty[py]+findy[py] 1833
# 3
# save3
# Loading training data:P_01443
# (4504, 2920)
# howbig 158
# x_start [0]
# x_length [4503]
# y_start [0, 311, 313, 821]
# y_length [309, 1, 507, 1230]
# start[p] 0
# start[p]+find[p] 4503
# starty[py] 821
# starty[py]+findy[py] 2051
# 3
# save3
# Loading training data:P_01446
# (5491, 2851)
# howbig 201
# x_start [0]
# x_length [5490]
# y_start [0]
# y_length [2850]
# start[p] 0
# start[p]+find[p] 5490
# starty[py] 0
# starty[py]+findy[py] 2850
# 1
# save1
# Loading training data:P_01451
# (5744, 4008)
# howbig 267
# x_start [0]
# x_length [5743]
# y_start [0, 219, 228, 493]
# y_length [218, 8, 264, 2762]
# start[p] 0
# start[p]+find[p] 5743
# starty[py] 493
# starty[py]+findy[py] 3255
# 1
# save1
# Loading training data:P_01451
# (5760, 4072)
# howbig 385
# x_start [0]
# x_length [5759]
# y_start [0, 311, 357, 424, 628, 735, 836]
# y_length [310, 45, 66, 203, 106, 100, 2220]
# start[p] 0
# start[p]+find[p] 5759
# starty[py] 836
# starty[py]+findy[py] 3056
# 1
# save1
# Loading training data:P_01454
# (6601, 3676)
# howbig 455
# x_start [0]
# x_length [6600]
# y_start [0]
# y_length [3052]
# start[p] 0
# start[p]+find[p] 6600
# starty[py] 0
# starty[py]+findy[py] 3052
# 2
# save2
# Loading training data:P_01455
# (4760, 2672)
# howbig 447
# x_start [0, 100, 4056]
# x_length [98, 3955, 101]
# y_start [0]
# y_length [2671]
# start[p] 100
# start[p]+find[p] 4055
# starty[py] 0
# starty[py]+findy[py] 2671
# 1
# save1
# Loading training data:P_01455
# (4800, 2648)
# howbig 109
# x_start [0]
# x_length [4799]
# y_start [0]
# y_length [2647]
# start[p] 0
# start[p]+find[p] 4799
# starty[py] 0
# starty[py]+findy[py] 2647
# 1
# save1
# Loading training data:P_01456
# (4752, 2920)
# howbig 281
# x_start [0]
# x_length [4751]
# y_start [0]
# y_length [2919]
# start[p] 0
# start[p]+find[p] 4751
# starty[py] 0
# starty[py]+findy[py] 2919
# 2
# save2
# Loading training data:P_01456
# (4720, 2968)
# howbig 131
# x_start [0]
# x_length [4719]
# y_start [0, 2374, 2380, 2386]
# y_length [2373, 5, 5, 497]
# start[p] 0
# start[p]+find[p] 4719
# starty[py] 0
# starty[py]+findy[py] 2373
# 2
# save2
# Loading training data:P_01457
# (4528, 3032)
# howbig 384
# x_start [0, 98, 4156]
# x_length [97, 4057, 138]
# y_start [0, 1836, 1919, 1954]
# y_length [1835, 82, 34, 8]
# start[p] 98
# start[p]+find[p] 4155
# starty[py] 0
# starty[py]+findy[py] 1835
# 2
# save2
# Loading training data:P_01457
# (4472, 2760)
# howbig 457
# x_start [0]
# x_length [4471]
# y_start [0, 2152, 2206]
# y_length [2151, 53, 115]
# start[p] 0
# start[p]+find[p] 4471
# starty[py] 0
# starty[py]+findy[py] 2151
# 2
# save2
# Loading training data:P_01457
# (4616, 3040)
# howbig 103
# x_start [0]
# x_length [4615]
# y_start [0]
# y_length [3039]
# start[p] 0
# start[p]+find[p] 4615
# starty[py] 0
# starty[py]+findy[py] 3039
# 2
# save2
# Loading training data:P_01457
# (4576, 3016)
# howbig 381
# x_start [0]
# x_length [4575]
# y_start [0, 190, 192, 415]
# y_length [189, 1, 222, 2209]
# start[p] 0
# start[p]+find[p] 4575
# starty[py] 415
# starty[py]+findy[py] 2624
# 2
# save2
# Loading training data:P_01458
# (4552, 2864)
# howbig 295
# x_start [0]
# x_length [4551]
# y_start [0, 1192, 1194, 1654]
# y_length [1191, 1, 459, 207]
# start[p] 0
# start[p]+find[p] 4551
# starty[py] 0
# starty[py]+findy[py] 1191
# 3
# save3
# Loading training data:P_01458
# (4544, 2840)
# howbig 154
# x_start [0]
# x_length [4543]
# y_start [0, 1420, 1426]
# y_length [1419, 3, 858]
# start[p] 0
# start[p]+find[p] 4543
# starty[py] 0
# starty[py]+findy[py] 1419
# 3
# save3
# Loading training data:P_01459
# (4351, 2086)
# howbig 335
# x_start [0, 3755]
# x_length [3747, 1]
# y_start [0, 248]
# y_length [247, 1259]
# start[p] 0
# start[p]+find[p] 3747
# starty[py] 248
# starty[py]+findy[py] 1507
# 4
# save4
# Loading training data:P_01459
# (5491, 2491)
# howbig 370
# x_start [0]
# x_length [5490]
# y_start [0]
# y_length [2490]
# start[p] 0
# start[p]+find[p] 5490
# starty[py] 0
# starty[py]+findy[py] 2490
# 4
# save4
# Loading training data:P_01462
# (4544, 3120)
# howbig 178
# x_start [0]
# x_length [4543]
# y_start [0, 1837, 2143, 2169]
# y_length [1836, 305, 25, 18]
# start[p] 0
# start[p]+find[p] 4543
# starty[py] 0
# starty[py]+findy[py] 1836
# 2
# save2
# Loading training data:P_01462
# (4536, 3112)
# howbig 478
# x_start [0]
# x_length [4535]
# y_start [0, 1933, 2138]
# y_length [1932, 204, 8]
# start[p] 0
# start[p]+find[p] 4535
# starty[py] 0
# starty[py]+findy[py] 1932
# 2
# save2
# Loading training data:P_01467
# (4728, 3128)
# howbig 181
# x_start [0]
# x_length [4727]
# y_start [0]
# y_length [3127]
# start[p] 0
# start[p]+find[p] 4727
# starty[py] 0
# starty[py]+findy[py] 3127
# 3
# save3
# Loading training data:P_01467
# (4744, 3096)
# howbig 396
# x_start [0, 4146]
# x_length [4143, 190]
# y_start [0]
# y_length [3095]
# start[p] 0
# start[p]+find[p] 4143
# starty[py] 0
# starty[py]+findy[py] 3095
# 3
# save3
# Loading training data:P_01472
# (5326, 3046)
# howbig 492
# x_start [1, 3]
# x_length [1, 4705]
# y_start [0, 2439]
# y_length [2437, 356]
# start[p] 3
# start[p]+find[p] 4708
# starty[py] 0
# starty[py]+findy[py] 2437
# 4
# save4
# Loading training data:P_01478
# (4592, 2640)
# howbig 301
# x_start [0, 3922, 3926, 3928, 3932, 3935, 3938, 3943, 3945, 3947, 3950, 3957, 3962, 3965, 3971, 3977, 3982, 3986, 3990, 3993, 3999, 4004, 4007, 4014]
# x_length [3921, 2, 1, 1, 1, 1, 1, 1, 1, 2, 2, 1, 1, 5, 1, 1, 3, 3, 2, 5, 3, 2, 6, 148]
# y_start [0]
# y_length [2639]
# start[p] 0
# start[p]+find[p] 3921
# starty[py] 0
# starty[py]+findy[py] 2639
# 2
# save2
# Loading training data:P_01478
# (4632, 2640)
# howbig 128
# x_start [0]
# x_length [4631]
# y_start [0]
# y_length [2639]
# start[p] 0
# start[p]+find[p] 4631
# starty[py] 0
# starty[py]+findy[py] 2639
# 2
# save2
# Loading training data:P_01487
# (4592, 3056)
# howbig 388
# x_start [0]
# x_length [4591]
# y_start [0, 710]
# y_length [709, 1762]
# start[p] 0
# start[p]+find[p] 4591
# starty[py] 710
# starty[py]+findy[py] 2472
# 2
# save2
# Loading training data:P_01488
# (4688, 2712)
# howbig 402
# x_start [0, 78, 231, 3621, 3666]
# x_length [77, 151, 3389, 44, 258]
# y_start [0]
# y_length [2711]
# start[p] 231
# start[p]+find[p] 3620
# starty[py] 0
# starty[py]+findy[py] 2711
# 3
# save3
# Loading training data:P_01488
# (4704, 2640)
# howbig 146
# x_start [0, 3955, 3972, 3981]
# x_length [3954, 16, 8, 719]
# y_start [0]
# y_length [2639]
# start[p] 0
# start[p]+find[p] 3954
# starty[py] 0
# starty[py]+findy[py] 2639
# 3
# save3
# Loading training data:P_01497
# (5491, 2371)
# howbig 171
# x_start [0]
# x_length [5490]
# y_start [0]
# y_length [2370]
# start[p] 0
# start[p]+find[p] 5490
# starty[py] 0
# starty[py]+findy[py] 2370
# 4
# save4
# Loading training data:P_01497
# (5491, 2416)
# howbig 213
# x_start [0]
# x_length [5490]
# y_start [0]
# y_length [2415]
# start[p] 0
# start[p]+find[p] 5490
# starty[py] 0
# starty[py]+findy[py] 2415
# 4
# save4
# Loading training data:P_01497
# (5386, 2461)
# howbig 169
# x_start [0]
# x_length [5385]
# y_start [0]
# y_length [2460]
# start[p] 0
# start[p]+find[p] 5385
# starty[py] 0
# starty[py]+findy[py] 2460
# 4
# save4
# Loading training data:P_01505
# (4712, 3056)
# howbig 190
# x_start [0, 143, 146, 3657, 3669, 3681, 3685]
# x_length [142, 1, 3510, 11, 11, 3, 114]
# y_start [0]
# y_length [3055]
# start[p] 146
# start[p]+find[p] 3656
# starty[py] 0
# starty[py]+findy[py] 3055
# 3
# save3
# Loading training data:P_01505
# (4632, 3152)
# howbig 203
# x_start [0]
# x_length [4631]
# y_start [0]
# y_length [3151]
# start[p] 0
# start[p]+find[p] 4631
# starty[py] 0
# starty[py]+findy[py] 3151
# 3
# save3
# Loading training data:P_01513
# (4464, 2896)
# howbig 119
# x_start [0]
# x_length [4463]
# y_start [0, 2387, 2477]
# y_length [2386, 89, 3]
# start[p] 0
# start[p]+find[p] 4463
# starty[py] 0
# starty[py]+findy[py] 2386
# 2
# save2
# Loading training data:P_01513
# (4240, 2896)
# howbig 326
# x_start [0]
# x_length [4239]
# y_start [0]
# y_length [2325]
# start[p] 0
# start[p]+find[p] 4239
# starty[py] 0
# starty[py]+findy[py] 2325
# 2
# save2
# Loading training data:P_01517
# (4606, 2221)
# howbig 267
# x_start [0]
# x_length [4605]
# y_start [0, 58, 63, 67, 70, 72, 75, 171, 202]
# y_length [56, 3, 3, 1, 1, 2, 95, 30, 1907]
# start[p] 0
# start[p]+find[p] 4605
# starty[py] 202
# starty[py]+findy[py] 2109
# 4
# save4
# Loading training data:P_01522
# (5880, 3472)
# howbig 274
# x_start [0, 125]
# x_length [124, 5477]
# y_start [0]
# y_length [3471]
# start[p] 125
# start[p]+find[p] 5602
# starty[py] 0
# starty[py]+findy[py] 3471
# 2
# save2
# Loading training data:P_01522
# (5936, 3848)
# howbig 438
# x_start [0, 5261]
# x_length [5260, 178]
# y_start [0]
# y_length [3847]
# start[p] 0
# start[p]+find[p] 5260
# starty[py] 0
# starty[py]+findy[py] 3847
# 2
# save2
# Loading training data:P_01524
# (5131, 2761)
# howbig 439
# x_start [0]
# x_length [5130]
# y_start [0, 136, 196]
# y_length [135, 59, 2069]
# start[p] 0
# start[p]+find[p] 5130
# starty[py] 196
# starty[py]+findy[py] 2265
# 3
# save3
# Loading training data:P_01524
# (5251, 2761)
# howbig 219
# x_start [0]
# x_length [5250]
# y_start [1]
# y_length [2300]
# start[p] 0
# start[p]+find[p] 5250
# starty[py] 1
# starty[py]+findy[py] 2301
# 3
# save3
# Loading training data:P_01526
# (5960, 3928)
# howbig 364
# x_start [0, 55, 391, 4253]
# x_length [54, 335, 3861, 139]
# y_start [0]
# y_length [3927]
# start[p] 391
# start[p]+find[p] 4252
# starty[py] 0
# starty[py]+findy[py] 3927
# 2
# save2
# Loading training data:P_01526
# (5944, 3744)
# howbig 265
# x_start [0]
# x_length [5943]
# y_start [0]
# y_length [3743]
# start[p] 0
# start[p]+find[p] 5943
# starty[py] 0
# starty[py]+findy[py] 3743
# 2
# save2
# Loading training data:P_01537
# (5476, 3286)
# howbig 319
# x_start [0]
# x_length [5475]
# y_start [0]
# y_length [3285]
# start[p] 0
# start[p]+find[p] 5475
# starty[py] 0
# starty[py]+findy[py] 3285
# 4
# save4
# Loading training data:P_01545
# (5251, 2326)
# howbig 112
# x_start [0]
# x_length [5250]
# y_start [0, 1837, 1853, 1857, 1859, 1863]
# y_length [1836, 14, 3, 1, 3, 5]
# start[p] 0
# start[p]+find[p] 5250
# starty[py] 0
# starty[py]+findy[py] 1836
# 3
# save3
# Loading training data:P_01545
# (6226, 2701)
# howbig 220
# x_start [0]
# x_length [6225]
# y_start [0]
# y_length [2700]
# start[p] 0
# start[p]+find[p] 6225
# starty[py] 0
# starty[py]+findy[py] 2700
# 3
# save3
# Loading training data:P_01548
# (3721, 1681)
# howbig 298
# x_start [0]
# x_length [3720]
# y_start [0]
# y_length [1680]
# start[p] 0
# start[p]+find[p] 3720
# starty[py] 0
# starty[py]+findy[py] 1680
# 3
# save3
# Loading training data:P_01548
# (5311, 2116)
# howbig 213
# x_start [0]
# x_length [5305]
# y_start [0]
# y_length [2115]
# start[p] 0
# start[p]+find[p] 5305
# starty[py] 0
# starty[py]+findy[py] 2115
# 3
# save3
# Loading training data:P_01549
# (5101, 3271)
# howbig 347
# x_start [0, 59, 62]
# x_length [57, 2, 4124]
# y_start [0, 19]
# y_length [18, 2599]
# start[p] 62
# start[p]+find[p] 4186
# starty[py] 19
# starty[py]+findy[py] 2618
# 3
# save3
# Loading training data:P_01549
# (6631, 3736)
# howbig 328
# x_start [0]
# x_length [6630]
# y_start [0]
# y_length [3735]
# start[p] 0
# start[p]+find[p] 6630
# starty[py] 0
# starty[py]+findy[py] 3735
# 3
# save3
# Loading training data:P_01561
# (5688, 3992)
# howbig 115
# x_start [0]
# x_length [5687]
# y_start [0, 3106, 3194]
# y_length [3105, 87, 52]
# start[p] 0
# start[p]+find[p] 5687
# starty[py] 0
# starty[py]+findy[py] 3105
# 2
# save2
# Loading training data:P_01561
# (5752, 3976)
# howbig 148

# %%
    splity=[1,2,3,4,7,8,9,11,12,31,32,37,38,39,40,41,42,43]
    county=0
    starty=[]
    findy=[]
    splity.append(0)
    print(splity)
    for i in range(len(splity)-1):
        if splity[i+1]-splity[i]==1:
            if county==0:
                starty.append(i)
            county=county+1
        else:
            if county != 0:
                findy.append(county)
                print('y_len',county)
            county=0
    py=findy.index(max(findy)) 

    print('y_start',starty)
    print('y_length',findy)
    print(splity[starty[py]:starty[py]+findy[py]+1])
# Out:
# [1, 2, 3, 4, 7, 8, 9, 11, 12, 31, 32, 37, 38, 39, 40, 41, 42, 43, 0]
# y_len 3
# y_len 2
# y_len 1
# y_len 1
# y_len 6
# y_start [0, 4, 7, 9, 11]
# y_length [3, 2, 1, 1, 6]
# [37, 38, 39, 40, 41, 42, 43]
